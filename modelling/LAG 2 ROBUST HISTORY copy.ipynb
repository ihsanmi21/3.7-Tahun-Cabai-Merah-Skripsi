# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.dates as mdates
sns.set_style('whitegrid')
# %matplotlib inline
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, Dropout,GRU
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from tensorflow.keras import optimizers, Model
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Load Data

# %%
import os
CURR_FOLDER_PATH = os.getcwd()
BASE_PATH = os.path.dirname(os.path.dirname(CURR_FOLDER_PATH))
DATA_PATH = os.path.join(BASE_PATH, 'Lulus/data')

# %%
df = pd.read_excel(DATA_PATH + '/Harga cabai gabungan lag-2.xlsx')
# Data yang digunakan yaitu Harga cabai Rawit dan Harga Bawang putih sebagai Barang Subtitusi Sudah dilakukan lag - 1 Minggu

# %%
df
# Out:
#           Tanggal Harga Cabai Rawit Harga Cabai Merah
# 0    01/ 01/ 2018             26200                 -
# 1    08/ 01/ 2018                 -             38300
# 2    15/ 01/ 2018                 -             42800
# 3    22/ 01/ 2018             42600             37850
# 4    29/ 01/ 2018             42700             38950
# ..            ...               ...               ...
# 308  27/ 11/ 2023             75250             80250
# 309  04/ 12/ 2023             76600             94900
# 310  11/ 12/ 2023             79150             99300
# 311  18/ 12/ 2023             79100             85000
# 312  25/ 12/ 2023             75550                 -
#
# [313 rows x 3 columns]

# %% [markdown]
# # Statistical Analytics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tanggal            313 non-null    object
#  1   Harga Cabai Rawit  313 non-null    object
#  2   Harga Cabai Merah  313 non-null    object
# dtypes: object(3)
# memory usage: 7.5+ KB

# %%
df.shape
# Out:
# (313, 3)

# %%
df.replace('-', pd.NA, inplace=True)

# %%
missing_values = df.isnull().sum()
percentage_missing = (missing_values / df.shape[0]) * 100
print("Jumlah Missing Value per Kolom:")
print(missing_values)
print("\nPersentase Missing Value per Kolom:")
percentage_missing
# Out:
# Jumlah Missing Value per Kolom:
# Tanggal              0
# Harga Cabai Rawit    9
# Harga Cabai Merah    9
# dtype: int64
#
# Persentase Missing Value per Kolom:
# Tanggal              0.000000
# Harga Cabai Rawit    2.875399
# Harga Cabai Merah    2.875399
# dtype: float64

# %%
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/ %m/ %Y')
df['Bulan'] = df['Tanggal'].dt.to_period('M')
mean_values = df.groupby('Bulan').mean()


def fill_missing_with_mean(row):
    if pd.isna(row['Harga Cabai Merah']):
        row['Harga Cabai Merah'] = mean_values.loc[row['Bulan'], 'Harga Cabai Merah']
    if pd.isna(row['Harga Cabai Rawit']):
        row['Harga Cabai Rawit'] = mean_values.loc[row['Bulan'], 'Harga Cabai Rawit']
    return row


df = df.apply(fill_missing_with_mean, axis=1)
print(df)
# Out:
#        Tanggal  Harga Cabai Rawit  Harga Cabai Merah    Bulan
# 0   2018-01-01       26200.000000       39475.000000  2018-01
# 1   2018-01-08       37166.666667       38300.000000  2018-01
# 2   2018-01-15       37166.666667       42800.000000  2018-01
# 3   2018-01-22       42600.000000       37850.000000  2018-01
# 4   2018-01-29       42700.000000       38950.000000  2018-01
# ..         ...                ...                ...      ...
# 308 2023-11-27       75250.000000       80250.000000  2023-11
# 309 2023-12-04       76600.000000       94900.000000  2023-12
# 310 2023-12-11       79150.000000       99300.000000  2023-12
# 311 2023-12-18       79100.000000       85000.000000  2023-12
# 312 2023-12-25       75550.000000       93066.666667  2023-12
#
# [313 rows x 4 columns]

# %%
df['Harga Cabai Merah'] = df['Harga Cabai Merah'].astype('float64')
df['Harga Cabai Rawit'] = df['Harga Cabai Rawit'].astype('float64')

# %%
import seaborn as sns

harga_merah_stats = df['Harga Cabai Merah'].describe()
print("\nStatistik Deskriptif Harga Cabai Merah:")
print(harga_merah_stats)


harga_rawit_stats = df['Harga Cabai Rawit'].describe()
print("\nStatistik Deskriptif Harga Cabai Rawit:")
print(harga_rawit_stats)
# Out:
# Statistik Deskriptif Harga Cabai Merah:
# count       313.000000
# mean      43092.092652
# std       15493.651894
# min       21750.000000
# 25%       31650.000000
# 50%       40800.000000
# 75%       49550.000000
# max      109450.000000
# Name: Harga Cabai Merah, dtype: float64
#
# Statistik Deskriptif Harga Cabai Rawit:
# count       313.000000
# mean      44719.768371
# std       17208.540869
# min       22600.000000
# 25%       30950.000000
# 50%       41500.000000
# 75%       53800.000000
# max      100750.000000
# Name: Harga Cabai Rawit, dtype: float64

# %%
# Visualisasi
plt.figure(figsize=(25, 6))
plt.plot(df.index, df['Harga Cabai Merah'])
plt.title('Data Harga Cabai Merah 1 Januari 2018 - 31 Juli 2023')
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Merah')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Harga Cabai Merah'], kde=True)
plt.title('Distribusi Harga')
plt.xlabel('Harga Cabai Merah')
plt.ylabel('Frekuensi')
plt.show()

# %%
corr_with_target = df[['Harga Cabai Merah','Harga Cabai Rawit']].corr()
# Membuat heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr_with_target, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5,
                      annot_kws={"size": 25})  # Ukuran font diperbesar menjadi 25

# Memperbesar ukuran font label pada sumbu x dan y
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=20)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=20)

# Menambahkan judul
plt.title('Korelasi antara Harga Cabai Merah dan Barang Subtitusi', fontsize=16)

# Menampilkan heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
df.head()
sns.lmplot(x="Harga Cabai Merah", y="Harga Cabai Rawit", data=df)
plt.show()

# %%
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
sns.pairplot(df, diag_kind=None)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Ubah kolom 'Tanggal' menjadi tipe datetime dan tetapkan sebagai indeks
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/%m/%Y')
df.set_index('Tanggal', inplace=True)

# Melakukan dekomposisi musiman
decomposition = seasonal_decompose(df['Harga Cabai Merah'], model='additive')

# Menampilkan hasil
plt.figure(figsize=(15, 8))

# Data asli
plt.subplot(411)
plt.plot(df.index, df['Harga Cabai Merah'], label='Original')
plt.legend(loc='upper left')

# Trend
plt.subplot(412)
plt.plot(decomposition.trend.index, decomposition.trend, label='Trend')
plt.legend(loc='upper left')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing Data

# %%
scaler_rr = MinMaxScaler(feature_range=(0, 1))
scaler_harga = MinMaxScaler(feature_range=(0, 1))
df['Harga Cabai Merah_Scaled'] = scaler_harga.fit_transform(df[['Harga Cabai Merah']])
df['Harga Cabai Rawit_Scaled'] = scaler_rr.fit_transform(df[['Harga Cabai Rawit']])

# %%
df.head()
# Out:
#             Harga Cabai Rawit  Harga Cabai Merah    Bulan  \
# Tanggal
# 2018-01-01       26200.000000            39475.0  2018-01
# 2018-01-08       37166.666667            38300.0  2018-01
# 2018-01-15       37166.666667            42800.0  2018-01
# 2018-01-22       42600.000000            37850.0  2018-01
# 2018-01-29       42700.000000            38950.0  2018-01
#
#             Harga Cabai Merah_Scaled  Harga Cabai Rawit_Scaled
# Tanggal
# 2018-01-01                  0.202109                  0.046065
# 2018-01-08                  0.188712                  0.186394
# 2018-01-15                  0.240023                  0.186394
# 2018-01-22                  0.183580                  0.255918
# 2018-01-29                  0.196123                  0.257198

# %% [markdown]
# # Split Data

# %%
from sklearn.model_selection import train_test_split

selected_columns = ['Harga Cabai Merah_Scaled', 'Harga Cabai Rawit_Scaled']
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)][selected_columns].values
        dataX.append(a)
        dataY.append(dataset[i + look_back:i + look_back + 1]['Harga Cabai Merah_Scaled'].values)
    return np.array(dataX), np.array(dataY)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Memisahkan 20% data latih sebagai data validasi tanpa mengacak urutan waktu
trainX, valX, trainY, valY = train_test_split(trainX, trainY, test_size=0.2, shuffle=False)

print("Ukuran data latih setelah pembagian:", trainX.shape)
print("Ukuran data validasi setelah pembagian:", valX.shape)
print("Ukuran data uji:", testX.shape)
# Out:
# Ukuran data latih setelah pembagian: (199, 1, 2)
# Ukuran data validasi setelah pembagian: (50, 1, 2)
# Ukuran data uji: (62, 1, 2)

# %% [markdown]
# # Pembuatan Model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# List parameter yang akan diuji
units_list = [10, 30, 50, 70, 90, 110, 130, 150, 170, 200]
epochs_list = [50, 70, 90, 110, 130, 150, 170, 200]
batch_size_list = [8, 16, 32, 64, 128]

# Loop untuk mencoba semua kombinasi parameter
for units in units_list:
    for epochs in epochs_list:
        for batch_size in batch_size_list:
            # Membuat model
            model = Sequential()
            model.add(LSTM(units=units, return_sequences=True, input_shape=(look_back, 2), activation='relu'))
            model.add(LSTM(units=units, activation='relu'))
            model.add(Dense(units=1, activation='linear'))
            model.compile(optimizer='adam', loss='mean_squared_error')
            # Melatih model dengan validation_data
            history = model.fit(trainX, trainY, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=(valX, valY))
            # Mendapatkan validation loss
            val_loss = np.min(history.history['val_loss'])
            # Mencetak hasil
            print(f"Units: {units}, Epochs: {epochs}, Batch Size: {batch_size}, Validation Loss: {val_loss}")
# Out:
# Units: 10, Epochs: 50, Batch Size: 8, Validation Loss: 0.013475230894982815
# Units: 10, Epochs: 50, Batch Size: 16, Validation Loss: 0.01169426366686821
# Units: 10, Epochs: 50, Batch Size: 32, Validation Loss: 0.019376114010810852
# Units: 10, Epochs: 50, Batch Size: 64, Validation Loss: 0.05310489237308502
# Units: 10, Epochs: 50, Batch Size: 128, Validation Loss: 0.07548195868730545
# Units: 10, Epochs: 70, Batch Size: 8, Validation Loss: 0.008501666598021984
# Units: 10, Epochs: 70, Batch Size: 16, Validation Loss: 0.009065045043826103
# Units: 10, Epochs: 70, Batch Size: 32, Validation Loss: 0.007904578000307083
# Units: 10, Epochs: 70, Batch Size: 64, Validation Loss: 0.02021174691617489
# Units: 10, Epochs: 70, Batch Size: 128, Validation Loss: 0.040576063096523285
# Units: 10, Epochs: 90, Batch Size: 8, Validation Loss: 0.009715166874229908
# Units: 10, Epochs: 90, Batch Size: 16, Validation Loss: 0.008876089006662369
# Units: 10, Epochs: 90, Batch Size: 32, Validation Loss: 0.010905507020652294
# Units: 10, Epochs: 90, Batch Size: 64, Validation Loss: 0.01529153622686863
# Units: 10, Epochs: 90, Batch Size: 128, Validation Loss: 0.04319930449128151
# Units: 10, Epochs: 110, Batch Size: 8, Validation Loss: 0.006793513894081116
# Units: 10, Epochs: 110, Batch Size: 16, Validation Loss: 0.0061277528293430805
# Units: 10, Epochs: 110, Batch Size: 32, Validation Loss: 0.011035547591745853
# Units: 10, Epochs: 110, Batch Size: 64, Validation Loss: 0.010079938918352127
# Units: 10, Epochs: 110, Batch Size: 128, Validation Loss: 0.02544066496193409
# Units: 10, Epochs: 130, Batch Size: 8, Validation Loss: 0.0066933403722941875
# Units: 10, Epochs: 130, Batch Size: 16, Validation Loss: 0.0068986969999969006
# Units: 10, Epochs: 130, Batch Size: 32, Validation Loss: 0.07846260070800781
# Units: 10, Epochs: 130, Batch Size: 64, Validation Loss: 0.013332697562873363
# Units: 10, Epochs: 130, Batch Size: 128, Validation Loss: 0.03692328929901123
# Units: 10, Epochs: 150, Batch Size: 8, Validation Loss: 0.006733670365065336
# Units: 10, Epochs: 150, Batch Size: 16, Validation Loss: 0.007545938715338707
# Units: 10, Epochs: 150, Batch Size: 32, Validation Loss: 0.01034292858093977
# Units: 10, Epochs: 150, Batch Size: 64, Validation Loss: 0.01174716092646122
# Units: 10, Epochs: 150, Batch Size: 128, Validation Loss: 0.01732178032398224
# Units: 10, Epochs: 170, Batch Size: 8, Validation Loss: 0.006257316563278437
# Units: 10, Epochs: 170, Batch Size: 16, Validation Loss: 0.006261439993977547
# Units: 10, Epochs: 170, Batch Size: 32, Validation Loss: 0.008422380313277245
# Units: 10, Epochs: 170, Batch Size: 64, Validation Loss: 0.010839556343853474
# Units: 10, Epochs: 170, Batch Size: 128, Validation Loss: 0.012611495330929756
# Units: 10, Epochs: 200, Batch Size: 8, Validation Loss: 0.0060216281563043594
# Units: 10, Epochs: 200, Batch Size: 16, Validation Loss: 0.0066862814128398895
# Units: 10, Epochs: 200, Batch Size: 32, Validation Loss: 0.0072881923988461494
# Units: 10, Epochs: 200, Batch Size: 64, Validation Loss: 0.010762713849544525
# Units: 10, Epochs: 200, Batch Size: 128, Validation Loss: 0.012312429025769234
# Units: 30, Epochs: 50, Batch Size: 8, Validation Loss: 0.009891968220472336
# Units: 30, Epochs: 50, Batch Size: 16, Validation Loss: 0.009998342022299767
# Units: 30, Epochs: 50, Batch Size: 32, Validation Loss: 0.010557190515100956
# Units: 30, Epochs: 50, Batch Size: 64, Validation Loss: 0.027631334960460663
# Units: 30, Epochs: 50, Batch Size: 128, Validation Loss: 0.037484411150217056
# Units: 30, Epochs: 70, Batch Size: 8, Validation Loss: 0.007125575561076403
# Units: 30, Epochs: 70, Batch Size: 16, Validation Loss: 0.008278930559754372
# Units: 30, Epochs: 70, Batch Size: 32, Validation Loss: 0.008246349170804024
# Units: 30, Epochs: 70, Batch Size: 64, Validation Loss: 0.011893007904291153
# Units: 30, Epochs: 70, Batch Size: 128, Validation Loss: 0.02887907810509205
# Units: 30, Epochs: 90, Batch Size: 8, Validation Loss: 0.005961839109659195
# Units: 30, Epochs: 90, Batch Size: 16, Validation Loss: 0.0067723942920565605
# Units: 30, Epochs: 90, Batch Size: 32, Validation Loss: 0.0074413311667740345
# Units: 30, Epochs: 90, Batch Size: 64, Validation Loss: 0.011064662598073483
# Units: 30, Epochs: 90, Batch Size: 128, Validation Loss: 0.019137583673000336
# Units: 30, Epochs: 110, Batch Size: 8, Validation Loss: 0.006345552857965231
# Units: 30, Epochs: 110, Batch Size: 16, Validation Loss: 0.007405330426990986
# Units: 30, Epochs: 110, Batch Size: 32, Validation Loss: 0.008420061320066452
# Units: 30, Epochs: 110, Batch Size: 64, Validation Loss: 0.010705208405852318
# Units: 30, Epochs: 110, Batch Size: 128, Validation Loss: 0.017118025571107864
# Units: 30, Epochs: 130, Batch Size: 8, Validation Loss: 0.00630873441696167
# Units: 30, Epochs: 130, Batch Size: 16, Validation Loss: 0.006410851608961821
# Units: 30, Epochs: 130, Batch Size: 32, Validation Loss: 0.006613488309085369
# Units: 30, Epochs: 130, Batch Size: 64, Validation Loss: 0.010858286172151566
# Units: 30, Epochs: 130, Batch Size: 128, Validation Loss: 0.011412030085921288
# Units: 30, Epochs: 150, Batch Size: 8, Validation Loss: 0.005837810691446066
# Units: 30, Epochs: 150, Batch Size: 16, Validation Loss: 0.006506017409265041
# Units: 30, Epochs: 150, Batch Size: 32, Validation Loss: 0.00689550768584013
# Units: 30, Epochs: 150, Batch Size: 64, Validation Loss: 0.008748638443648815
# Units: 30, Epochs: 150, Batch Size: 128, Validation Loss: 0.011137575842440128
# Units: 30, Epochs: 170, Batch Size: 8, Validation Loss: 0.00616267928853631
# Units: 30, Epochs: 170, Batch Size: 16, Validation Loss: 0.0063488660380244255
# Units: 30, Epochs: 170, Batch Size: 32, Validation Loss: 0.006834039464592934
# Units: 30, Epochs: 170, Batch Size: 64, Validation Loss: 0.009581313468515873
# Units: 30, Epochs: 170, Batch Size: 128, Validation Loss: 0.010773147456347942
# Units: 30, Epochs: 200, Batch Size: 8, Validation Loss: 0.005922658368945122
# Units: 30, Epochs: 200, Batch Size: 16, Validation Loss: 0.00614880071952939
# Units: 30, Epochs: 200, Batch Size: 32, Validation Loss: 0.0064238267950713634
# Units: 30, Epochs: 200, Batch Size: 64, Validation Loss: 0.008197331801056862
# Units: 30, Epochs: 200, Batch Size: 128, Validation Loss: 0.01277262344956398
# Units: 50, Epochs: 50, Batch Size: 8, Validation Loss: 0.005907430779188871
# Units: 50, Epochs: 50, Batch Size: 16, Validation Loss: 0.00816604308784008
# Units: 50, Epochs: 50, Batch Size: 32, Validation Loss: 0.009155680425465107
# Units: 50, Epochs: 50, Batch Size: 64, Validation Loss: 0.012396070174872875
# Units: 50, Epochs: 50, Batch Size: 128, Validation Loss: 0.03553509712219238
# Units: 50, Epochs: 70, Batch Size: 8, Validation Loss: 0.00610776012763381
# Units: 50, Epochs: 70, Batch Size: 16, Validation Loss: 0.006785932928323746
# Units: 50, Epochs: 70, Batch Size: 32, Validation Loss: 0.009596390649676323
# Units: 50, Epochs: 70, Batch Size: 64, Validation Loss: 0.009027273394167423
# Units: 50, Epochs: 70, Batch Size: 128, Validation Loss: 0.022631216794252396
# Units: 50, Epochs: 90, Batch Size: 8, Validation Loss: 0.006026344373822212
# Units: 50, Epochs: 90, Batch Size: 16, Validation Loss: 0.006342345383018255
# Units: 50, Epochs: 90, Batch Size: 32, Validation Loss: 0.007373685948550701
# Units: 50, Epochs: 90, Batch Size: 64, Validation Loss: 0.009857481345534325
# Units: 50, Epochs: 90, Batch Size: 128, Validation Loss: 0.008832396008074284
# Units: 50, Epochs: 110, Batch Size: 8, Validation Loss: 0.006091499235481024
# Units: 50, Epochs: 110, Batch Size: 16, Validation Loss: 0.006135278847068548
# Units: 50, Epochs: 110, Batch Size: 32, Validation Loss: 0.0076943556778132915
# Units: 50, Epochs: 110, Batch Size: 64, Validation Loss: 0.00798783265054226
# Units: 50, Epochs: 110, Batch Size: 128, Validation Loss: 0.009147055447101593
# Units: 50, Epochs: 130, Batch Size: 8, Validation Loss: 0.00630051689222455
# Units: 50, Epochs: 130, Batch Size: 16, Validation Loss: 0.006304238922894001
# Units: 50, Epochs: 130, Batch Size: 32, Validation Loss: 0.006361599080264568
# Units: 50, Epochs: 130, Batch Size: 64, Validation Loss: 0.007742147892713547
# Units: 50, Epochs: 130, Batch Size: 128, Validation Loss: 0.009117555804550648
# Units: 50, Epochs: 150, Batch Size: 8, Validation Loss: 0.006043164059519768
# Units: 50, Epochs: 150, Batch Size: 16, Validation Loss: 0.006066880188882351
# Units: 50, Epochs: 150, Batch Size: 32, Validation Loss: 0.0065823765471577644
# Units: 50, Epochs: 150, Batch Size: 64, Validation Loss: 0.007317619398236275
# Units: 50, Epochs: 150, Batch Size: 128, Validation Loss: 0.009897413663566113
# Units: 50, Epochs: 170, Batch Size: 8, Validation Loss: 0.005957237910479307
# Units: 50, Epochs: 170, Batch Size: 16, Validation Loss: 0.006338789593428373
# Units: 50, Epochs: 170, Batch Size: 32, Validation Loss: 0.00629291171208024
# Units: 50, Epochs: 170, Batch Size: 64, Validation Loss: 0.006814535707235336
# Units: 50, Epochs: 170, Batch Size: 128, Validation Loss: 0.008613466285169125
# Units: 50, Epochs: 200, Batch Size: 8, Validation Loss: 0.006027244497090578
# Units: 50, Epochs: 200, Batch Size: 16, Validation Loss: 0.00626515643671155
# Units: 50, Epochs: 200, Batch Size: 32, Validation Loss: 0.0062079220078885555
# Units: 50, Epochs: 200, Batch Size: 64, Validation Loss: 0.007037646137177944
# Units: 50, Epochs: 200, Batch Size: 128, Validation Loss: 0.0074834395200014114
# Units: 70, Epochs: 50, Batch Size: 8, Validation Loss: 0.006170552223920822
# Units: 70, Epochs: 50, Batch Size: 16, Validation Loss: 0.006976238917559385
# Units: 70, Epochs: 50, Batch Size: 32, Validation Loss: 0.006998635362833738
# Units: 70, Epochs: 50, Batch Size: 64, Validation Loss: 0.01139647327363491
# Units: 70, Epochs: 50, Batch Size: 128, Validation Loss: 0.023318683728575706
# Units: 70, Epochs: 70, Batch Size: 8, Validation Loss: 0.006009984761476517
# Units: 70, Epochs: 70, Batch Size: 16, Validation Loss: 0.0063149887137115
# Units: 70, Epochs: 70, Batch Size: 32, Validation Loss: 0.007250440306961536
# Units: 70, Epochs: 70, Batch Size: 64, Validation Loss: 0.00857304036617279
# Units: 70, Epochs: 70, Batch Size: 128, Validation Loss: 0.01706327497959137
# Units: 70, Epochs: 90, Batch Size: 8, Validation Loss: 0.006087147165089846
# Units: 70, Epochs: 90, Batch Size: 16, Validation Loss: 0.00621868297457695
# Units: 70, Epochs: 90, Batch Size: 32, Validation Loss: 0.006790207698941231
# Units: 70, Epochs: 90, Batch Size: 64, Validation Loss: 0.00904392171651125
# Units: 70, Epochs: 90, Batch Size: 128, Validation Loss: 0.008684777654707432
# Units: 70, Epochs: 110, Batch Size: 8, Validation Loss: 0.005987727548927069
# Units: 70, Epochs: 110, Batch Size: 16, Validation Loss: 0.0061241639778018
# Units: 70, Epochs: 110, Batch Size: 32, Validation Loss: 0.006447909865528345
# Units: 70, Epochs: 110, Batch Size: 64, Validation Loss: 0.007707127369940281
# Units: 70, Epochs: 110, Batch Size: 128, Validation Loss: 0.00902451854199171
# Units: 70, Epochs: 130, Batch Size: 8, Validation Loss: 0.0061513022519648075
# Units: 70, Epochs: 130, Batch Size: 16, Validation Loss: 0.006233267020434141
# Units: 70, Epochs: 130, Batch Size: 32, Validation Loss: 0.006250249221920967
# Units: 70, Epochs: 130, Batch Size: 64, Validation Loss: 0.0073743159882724285
# Units: 70, Epochs: 130, Batch Size: 128, Validation Loss: 0.009167627431452274
# Units: 70, Epochs: 150, Batch Size: 8, Validation Loss: 0.006251235492527485
# Units: 70, Epochs: 150, Batch Size: 16, Validation Loss: 0.00613578362390399
# Units: 70, Epochs: 150, Batch Size: 32, Validation Loss: 0.006245441269129515
# Units: 70, Epochs: 150, Batch Size: 64, Validation Loss: 0.006561947986483574
# Units: 70, Epochs: 150, Batch Size: 128, Validation Loss: 0.007623395416885614
# Units: 70, Epochs: 170, Batch Size: 8, Validation Loss: 0.0059181214310228825
# Units: 70, Epochs: 170, Batch Size: 16, Validation Loss: 0.006356673315167427
# Units: 70, Epochs: 170, Batch Size: 32, Validation Loss: 0.006089707836508751
# Units: 70, Epochs: 170, Batch Size: 64, Validation Loss: 0.007527831941843033
# Units: 70, Epochs: 170, Batch Size: 128, Validation Loss: 0.007067844271659851
# Units: 70, Epochs: 200, Batch Size: 8, Validation Loss: 0.006010107230395079
# Units: 70, Epochs: 200, Batch Size: 16, Validation Loss: 0.006208451464772224
# Units: 70, Epochs: 200, Batch Size: 32, Validation Loss: 0.006050040014088154
# Units: 70, Epochs: 200, Batch Size: 64, Validation Loss: 0.006283134687691927
# Units: 70, Epochs: 200, Batch Size: 128, Validation Loss: 0.007733376231044531
# Units: 90, Epochs: 50, Batch Size: 8, Validation Loss: 0.005987222772091627
# Units: 90, Epochs: 50, Batch Size: 16, Validation Loss: 0.006535091903060675
# Units: 90, Epochs: 50, Batch Size: 32, Validation Loss: 0.00792428757995367
# Units: 90, Epochs: 50, Batch Size: 64, Validation Loss: 0.00824371725320816
# Units: 90, Epochs: 50, Batch Size: 128, Validation Loss: 0.019828464835882187
# Units: 90, Epochs: 70, Batch Size: 8, Validation Loss: 0.005984368734061718
# Units: 90, Epochs: 70, Batch Size: 16, Validation Loss: 0.006385633256286383
# Units: 90, Epochs: 70, Batch Size: 32, Validation Loss: 0.006849776022136211
# Units: 90, Epochs: 70, Batch Size: 64, Validation Loss: 0.007997571490705013
# Units: 90, Epochs: 70, Batch Size: 128, Validation Loss: 0.01139987725764513
# Units: 90, Epochs: 90, Batch Size: 8, Validation Loss: 0.006042259279638529
# Units: 90, Epochs: 90, Batch Size: 16, Validation Loss: 0.006319141946732998
# Units: 90, Epochs: 90, Batch Size: 32, Validation Loss: 0.006193860899657011
# Units: 90, Epochs: 90, Batch Size: 64, Validation Loss: 0.007093244697898626
# Units: 90, Epochs: 90, Batch Size: 128, Validation Loss: 0.008626031689345837
# Units: 90, Epochs: 110, Batch Size: 8, Validation Loss: 0.005835069343447685
# Units: 90, Epochs: 110, Batch Size: 16, Validation Loss: 0.0061093904078006744
# Units: 90, Epochs: 110, Batch Size: 32, Validation Loss: 0.006287903059273958
# Units: 90, Epochs: 110, Batch Size: 64, Validation Loss: 0.007438390050083399
# Units: 90, Epochs: 110, Batch Size: 128, Validation Loss: 0.00842054933309555
# Units: 90, Epochs: 130, Batch Size: 8, Validation Loss: 0.005996568128466606
# Units: 90, Epochs: 130, Batch Size: 16, Validation Loss: 0.006065594032406807
# Units: 90, Epochs: 130, Batch Size: 32, Validation Loss: 0.006037705112248659
# Units: 90, Epochs: 130, Batch Size: 64, Validation Loss: 0.006469566375017166
# Units: 90, Epochs: 130, Batch Size: 128, Validation Loss: 0.0071908836252987385
# Units: 90, Epochs: 150, Batch Size: 8, Validation Loss: 0.005892124958336353
# Units: 90, Epochs: 150, Batch Size: 16, Validation Loss: 0.005911068990826607
# Units: 90, Epochs: 150, Batch Size: 32, Validation Loss: 0.006155130919069052
# Units: 90, Epochs: 150, Batch Size: 64, Validation Loss: 0.006983128841966391
# Units: 90, Epochs: 150, Batch Size: 128, Validation Loss: 0.006997417658567429
# Units: 90, Epochs: 170, Batch Size: 8, Validation Loss: 0.0059882644563913345
# Units: 90, Epochs: 170, Batch Size: 16, Validation Loss: 0.006275066640228033
# Units: 90, Epochs: 170, Batch Size: 32, Validation Loss: 0.0061323558911681175
# Units: 90, Epochs: 170, Batch Size: 64, Validation Loss: 0.006373397074639797
# Units: 90, Epochs: 170, Batch Size: 128, Validation Loss: 0.00657468568533659
# Units: 90, Epochs: 200, Batch Size: 8, Validation Loss: 0.005893058609217405
# Units: 90, Epochs: 200, Batch Size: 16, Validation Loss: 0.006155305076390505
# Units: 90, Epochs: 200, Batch Size: 32, Validation Loss: 0.006136281415820122
# Units: 90, Epochs: 200, Batch Size: 64, Validation Loss: 0.006137525662779808
# Units: 90, Epochs: 200, Batch Size: 128, Validation Loss: 0.006509025115519762
# Units: 110, Epochs: 50, Batch Size: 8, Validation Loss: 0.00597055908292532
# Units: 110, Epochs: 50, Batch Size: 16, Validation Loss: 0.006345372647047043
# Units: 110, Epochs: 50, Batch Size: 32, Validation Loss: 0.006790223531424999
# Units: 110, Epochs: 50, Batch Size: 64, Validation Loss: 0.008016123436391354
# Units: 110, Epochs: 50, Batch Size: 128, Validation Loss: 0.013757768087089062
# Units: 110, Epochs: 70, Batch Size: 8, Validation Loss: 0.006054699420928955
# Units: 110, Epochs: 70, Batch Size: 16, Validation Loss: 0.006344003137201071
# Units: 110, Epochs: 70, Batch Size: 32, Validation Loss: 0.00668158195912838
# Units: 110, Epochs: 70, Batch Size: 64, Validation Loss: 0.007655394729226828
# Units: 110, Epochs: 70, Batch Size: 128, Validation Loss: 0.009290756657719612
# Units: 110, Epochs: 90, Batch Size: 8, Validation Loss: 0.005918390117585659
# Units: 110, Epochs: 90, Batch Size: 16, Validation Loss: 0.006121317856013775
# Units: 110, Epochs: 90, Batch Size: 32, Validation Loss: 0.006138109136372805
# Units: 110, Epochs: 90, Batch Size: 64, Validation Loss: 0.0065951962023973465
# Units: 110, Epochs: 90, Batch Size: 128, Validation Loss: 0.00792352482676506
# Units: 110, Epochs: 110, Batch Size: 8, Validation Loss: 0.006008146796375513
# Units: 110, Epochs: 110, Batch Size: 16, Validation Loss: 0.00612302590161562
# Units: 110, Epochs: 110, Batch Size: 32, Validation Loss: 0.0061151147820055485
# Units: 110, Epochs: 110, Batch Size: 64, Validation Loss: 0.006797286681830883
# Units: 110, Epochs: 110, Batch Size: 128, Validation Loss: 0.007571789436042309
# Units: 110, Epochs: 130, Batch Size: 8, Validation Loss: 0.0060831839218735695
# Units: 110, Epochs: 130, Batch Size: 16, Validation Loss: 0.006192820146679878
# Units: 110, Epochs: 130, Batch Size: 32, Validation Loss: 0.006015711929649115
# Units: 110, Epochs: 130, Batch Size: 64, Validation Loss: 0.0063040428794920444
# Units: 110, Epochs: 130, Batch Size: 128, Validation Loss: 0.0070952982641756535
# Units: 110, Epochs: 150, Batch Size: 8, Validation Loss: 0.006056615617126226
# Units: 110, Epochs: 150, Batch Size: 16, Validation Loss: 0.006178032141178846
# Units: 110, Epochs: 150, Batch Size: 32, Validation Loss: 0.006069600582122803
# Units: 110, Epochs: 150, Batch Size: 64, Validation Loss: 0.006598003674298525
# Units: 110, Epochs: 150, Batch Size: 128, Validation Loss: 0.007219593971967697
# Units: 110, Epochs: 170, Batch Size: 8, Validation Loss: 0.005933787208050489
# Units: 110, Epochs: 170, Batch Size: 16, Validation Loss: 0.00604112446308136
# Units: 110, Epochs: 170, Batch Size: 32, Validation Loss: 0.0061194938607513905
# Units: 110, Epochs: 170, Batch Size: 64, Validation Loss: 0.006069619674235582
# Units: 110, Epochs: 170, Batch Size: 128, Validation Loss: 0.006654885597527027
# Units: 110, Epochs: 200, Batch Size: 8, Validation Loss: 0.006002717185765505
# Units: 110, Epochs: 200, Batch Size: 16, Validation Loss: 0.006162781734019518
# Units: 110, Epochs: 200, Batch Size: 32, Validation Loss: 0.0061868941411376
# Units: 110, Epochs: 200, Batch Size: 64, Validation Loss: 0.006120542995631695
# Units: 110, Epochs: 200, Batch Size: 128, Validation Loss: 0.006477341055870056
# Units: 130, Epochs: 50, Batch Size: 8, Validation Loss: 0.0059644742868840694
# Units: 130, Epochs: 50, Batch Size: 16, Validation Loss: 0.00621809484437108
# Units: 130, Epochs: 50, Batch Size: 32, Validation Loss: 0.006862287409603596
# Units: 130, Epochs: 50, Batch Size: 64, Validation Loss: 0.006855941377580166
# Units: 130, Epochs: 50, Batch Size: 128, Validation Loss: 0.018346549943089485
# Units: 130, Epochs: 70, Batch Size: 8, Validation Loss: 0.005933685693889856
# Units: 130, Epochs: 70, Batch Size: 16, Validation Loss: 0.006163350306451321
# Units: 130, Epochs: 70, Batch Size: 32, Validation Loss: 0.006769484840333462
# Units: 130, Epochs: 70, Batch Size: 64, Validation Loss: 0.006952283903956413
# Units: 130, Epochs: 70, Batch Size: 128, Validation Loss: 0.009460139088332653
# Units: 130, Epochs: 90, Batch Size: 8, Validation Loss: 0.005974405910819769
# Units: 130, Epochs: 90, Batch Size: 16, Validation Loss: 0.006129434332251549
# Units: 130, Epochs: 90, Batch Size: 32, Validation Loss: 0.0063268463127315044
# Units: 130, Epochs: 90, Batch Size: 64, Validation Loss: 0.006941907573491335
# Units: 130, Epochs: 90, Batch Size: 128, Validation Loss: 0.007823879830539227
# Units: 130, Epochs: 110, Batch Size: 8, Validation Loss: 0.006073707714676857
# Units: 130, Epochs: 110, Batch Size: 16, Validation Loss: 0.00608871690928936
# Units: 130, Epochs: 110, Batch Size: 32, Validation Loss: 0.0062390947714447975
# Units: 130, Epochs: 110, Batch Size: 64, Validation Loss: 0.00671481154859066
# Units: 130, Epochs: 110, Batch Size: 128, Validation Loss: 0.00698889559134841
# Units: 130, Epochs: 130, Batch Size: 8, Validation Loss: 0.005983180366456509
# Units: 130, Epochs: 130, Batch Size: 16, Validation Loss: 0.0061538368463516235
# Units: 130, Epochs: 130, Batch Size: 32, Validation Loss: 0.006087275687605143
# Units: 130, Epochs: 130, Batch Size: 64, Validation Loss: 0.006218502297997475
# Units: 130, Epochs: 130, Batch Size: 128, Validation Loss: 0.006455979309976101
# Units: 130, Epochs: 150, Batch Size: 8, Validation Loss: 0.005960285197943449
# Units: 130, Epochs: 150, Batch Size: 16, Validation Loss: 0.006198199465870857
# Units: 130, Epochs: 150, Batch Size: 32, Validation Loss: 0.006017276551574469
# Units: 130, Epochs: 150, Batch Size: 64, Validation Loss: 0.00593411922454834
# Units: 130, Epochs: 150, Batch Size: 128, Validation Loss: 0.006610031705349684
# Units: 130, Epochs: 170, Batch Size: 8, Validation Loss: 0.005913502536714077
# Units: 130, Epochs: 170, Batch Size: 16, Validation Loss: 0.006158147938549519
# Units: 130, Epochs: 170, Batch Size: 32, Validation Loss: 0.006001342553645372
# Units: 130, Epochs: 170, Batch Size: 64, Validation Loss: 0.0061216508038342
# Units: 130, Epochs: 170, Batch Size: 128, Validation Loss: 0.006531198509037495
# Units: 130, Epochs: 200, Batch Size: 8, Validation Loss: 0.005930006969720125
# Units: 130, Epochs: 200, Batch Size: 16, Validation Loss: 0.006188566796481609
# Units: 130, Epochs: 200, Batch Size: 32, Validation Loss: 0.006020900793373585
# Units: 130, Epochs: 200, Batch Size: 64, Validation Loss: 0.006093374919146299
# Units: 130, Epochs: 200, Batch Size: 128, Validation Loss: 0.006304698530584574
# Units: 150, Epochs: 50, Batch Size: 8, Validation Loss: 0.006008152384310961
# Units: 150, Epochs: 50, Batch Size: 16, Validation Loss: 0.006303348578512669
# Units: 150, Epochs: 50, Batch Size: 32, Validation Loss: 0.006535964086651802
# Units: 150, Epochs: 50, Batch Size: 64, Validation Loss: 0.007728381548076868
# Units: 150, Epochs: 50, Batch Size: 128, Validation Loss: 0.014391737058758736
# Units: 150, Epochs: 70, Batch Size: 8, Validation Loss: 0.0059855105355381966
# Units: 150, Epochs: 70, Batch Size: 16, Validation Loss: 0.006167687941342592
# Units: 150, Epochs: 70, Batch Size: 32, Validation Loss: 0.006004192866384983
# Units: 150, Epochs: 70, Batch Size: 64, Validation Loss: 0.007085695862770081
# Units: 150, Epochs: 70, Batch Size: 128, Validation Loss: 0.007275106385350227
# Units: 150, Epochs: 90, Batch Size: 8, Validation Loss: 0.005850740242749453
# Units: 150, Epochs: 90, Batch Size: 16, Validation Loss: 0.006203606724739075
# Units: 150, Epochs: 90, Batch Size: 32, Validation Loss: 0.006168190389871597
# Units: 150, Epochs: 90, Batch Size: 64, Validation Loss: 0.006534946151077747
# Units: 150, Epochs: 90, Batch Size: 128, Validation Loss: 0.00733137084171176
# Units: 150, Epochs: 110, Batch Size: 8, Validation Loss: 0.005919025745242834
# Units: 150, Epochs: 110, Batch Size: 16, Validation Loss: 0.005903906654566526
# Units: 150, Epochs: 110, Batch Size: 32, Validation Loss: 0.006062767468392849
# Units: 150, Epochs: 110, Batch Size: 64, Validation Loss: 0.006220976822078228
# Units: 150, Epochs: 110, Batch Size: 128, Validation Loss: 0.007131748367100954
# Units: 150, Epochs: 130, Batch Size: 8, Validation Loss: 0.006022753659635782
# Units: 150, Epochs: 130, Batch Size: 16, Validation Loss: 0.006032335106283426
# Units: 150, Epochs: 130, Batch Size: 32, Validation Loss: 0.006063984706997871
# Units: 150, Epochs: 130, Batch Size: 64, Validation Loss: 0.0059603126719594
# Units: 150, Epochs: 130, Batch Size: 128, Validation Loss: 0.00667478796094656
# Units: 150, Epochs: 150, Batch Size: 8, Validation Loss: 0.006089609116315842
# Units: 150, Epochs: 150, Batch Size: 16, Validation Loss: 0.006036397069692612
# Units: 150, Epochs: 150, Batch Size: 32, Validation Loss: 0.006219071336090565
# Units: 150, Epochs: 150, Batch Size: 64, Validation Loss: 0.006119945552200079
# Units: 150, Epochs: 150, Batch Size: 128, Validation Loss: 0.006633162498474121
# Units: 150, Epochs: 170, Batch Size: 8, Validation Loss: 0.005903324112296104
# Units: 150, Epochs: 170, Batch Size: 16, Validation Loss: 0.006126371677964926
# Units: 150, Epochs: 170, Batch Size: 32, Validation Loss: 0.006002115085721016
# Units: 150, Epochs: 170, Batch Size: 64, Validation Loss: 0.006018367595970631
# Units: 150, Epochs: 170, Batch Size: 128, Validation Loss: 0.0064103431068360806
# Units: 150, Epochs: 200, Batch Size: 8, Validation Loss: 0.005956320557743311
# Units: 150, Epochs: 200, Batch Size: 16, Validation Loss: 0.006085691507905722
# Units: 150, Epochs: 200, Batch Size: 32, Validation Loss: 0.006094326265156269
# Units: 150, Epochs: 200, Batch Size: 64, Validation Loss: 0.00587958050891757
# Units: 150, Epochs: 200, Batch Size: 128, Validation Loss: 0.006465191021561623
# Units: 170, Epochs: 50, Batch Size: 8, Validation Loss: 0.006027899216860533
# Units: 170, Epochs: 50, Batch Size: 16, Validation Loss: 0.005986458621919155
# Units: 170, Epochs: 50, Batch Size: 32, Validation Loss: 0.0065402318723499775
# Units: 170, Epochs: 50, Batch Size: 64, Validation Loss: 0.006890329532325268
# Units: 170, Epochs: 50, Batch Size: 128, Validation Loss: 0.014144327491521835
# Units: 170, Epochs: 70, Batch Size: 8, Validation Loss: 0.005845727398991585
# Units: 170, Epochs: 70, Batch Size: 16, Validation Loss: 0.006092761177569628
# Units: 170, Epochs: 70, Batch Size: 32, Validation Loss: 0.006090054288506508
# Units: 170, Epochs: 70, Batch Size: 64, Validation Loss: 0.007125489879399538
# Units: 170, Epochs: 70, Batch Size: 128, Validation Loss: 0.00752902589738369
# Units: 170, Epochs: 90, Batch Size: 8, Validation Loss: 0.005998453125357628
# Units: 170, Epochs: 90, Batch Size: 16, Validation Loss: 0.0059786830097436905
# Units: 170, Epochs: 90, Batch Size: 32, Validation Loss: 0.006193718872964382
# Units: 170, Epochs: 90, Batch Size: 64, Validation Loss: 0.006177505478262901
# Units: 170, Epochs: 90, Batch Size: 128, Validation Loss: 0.007088919170200825
# Units: 170, Epochs: 110, Batch Size: 8, Validation Loss: 0.0059502762742340565
# Units: 170, Epochs: 110, Batch Size: 16, Validation Loss: 0.006109967827796936
# Units: 170, Epochs: 110, Batch Size: 32, Validation Loss: 0.006111526861786842
# Units: 170, Epochs: 110, Batch Size: 64, Validation Loss: 0.006163953337818384
# Units: 170, Epochs: 110, Batch Size: 128, Validation Loss: 0.00679264310747385
# Units: 170, Epochs: 130, Batch Size: 8, Validation Loss: 0.005923127755522728
# Units: 170, Epochs: 130, Batch Size: 16, Validation Loss: 0.006086592562496662
# Units: 170, Epochs: 130, Batch Size: 32, Validation Loss: 0.006080839782953262
# Units: 170, Epochs: 130, Batch Size: 64, Validation Loss: 0.0060071456246078014
# Units: 170, Epochs: 130, Batch Size: 128, Validation Loss: 0.0063458699733018875
# Units: 170, Epochs: 150, Batch Size: 8, Validation Loss: 0.005830066278576851
# Units: 170, Epochs: 150, Batch Size: 16, Validation Loss: 0.006132816895842552
# Units: 170, Epochs: 150, Batch Size: 32, Validation Loss: 0.006063718814402819
# Units: 170, Epochs: 150, Batch Size: 64, Validation Loss: 0.006068191025406122
# Units: 170, Epochs: 150, Batch Size: 128, Validation Loss: 0.006320953369140625
# Units: 170, Epochs: 170, Batch Size: 8, Validation Loss: 0.00584401423111558
# Units: 170, Epochs: 170, Batch Size: 16, Validation Loss: 0.006182556040585041
# Units: 170, Epochs: 170, Batch Size: 32, Validation Loss: 0.006058114115148783
# Units: 170, Epochs: 170, Batch Size: 64, Validation Loss: 0.005885602440685034
# Units: 170, Epochs: 170, Batch Size: 128, Validation Loss: 0.006249063182622194
# Units: 170, Epochs: 200, Batch Size: 8, Validation Loss: 0.005883309058845043
# Units: 170, Epochs: 200, Batch Size: 16, Validation Loss: 0.005889699328690767
# Units: 170, Epochs: 200, Batch Size: 32, Validation Loss: 0.005873244255781174
# Units: 170, Epochs: 200, Batch Size: 64, Validation Loss: 0.006004390772432089
# Units: 170, Epochs: 200, Batch Size: 128, Validation Loss: 0.006283690221607685
# Units: 200, Epochs: 50, Batch Size: 8, Validation Loss: 0.005884638521820307
# Units: 200, Epochs: 50, Batch Size: 16, Validation Loss: 0.006118336692452431
# Units: 200, Epochs: 50, Batch Size: 32, Validation Loss: 0.00627070851624012
# Units: 200, Epochs: 50, Batch Size: 64, Validation Loss: 0.0070896148681640625
# Units: 200, Epochs: 50, Batch Size: 128, Validation Loss: 0.008872668258845806
# Units: 200, Epochs: 70, Batch Size: 8, Validation Loss: 0.005902604665607214
# Units: 200, Epochs: 70, Batch Size: 16, Validation Loss: 0.0060935253277421
# Units: 200, Epochs: 70, Batch Size: 32, Validation Loss: 0.005954335909336805
# Units: 200, Epochs: 70, Batch Size: 64, Validation Loss: 0.006372425705194473
# Units: 200, Epochs: 70, Batch Size: 128, Validation Loss: 0.007123746443539858
# Units: 200, Epochs: 90, Batch Size: 8, Validation Loss: 0.005826834589242935
# Units: 200, Epochs: 90, Batch Size: 16, Validation Loss: 0.005972216837108135
# Units: 200, Epochs: 90, Batch Size: 32, Validation Loss: 0.006242942065000534
# Units: 200, Epochs: 90, Batch Size: 64, Validation Loss: 0.006358195096254349
# Units: 200, Epochs: 90, Batch Size: 128, Validation Loss: 0.00684686005115509
# Units: 200, Epochs: 110, Batch Size: 8, Validation Loss: 0.005929746199399233
# Units: 200, Epochs: 110, Batch Size: 16, Validation Loss: 0.006137436721473932
# Units: 200, Epochs: 110, Batch Size: 32, Validation Loss: 0.005988172255456448
# Units: 200, Epochs: 110, Batch Size: 64, Validation Loss: 0.006063361186534166
# Units: 200, Epochs: 110, Batch Size: 128, Validation Loss: 0.006541877519339323
# Units: 200, Epochs: 130, Batch Size: 8, Validation Loss: 0.005806541070342064
# Units: 200, Epochs: 130, Batch Size: 16, Validation Loss: 0.005917588248848915
# Units: 200, Epochs: 130, Batch Size: 32, Validation Loss: 0.0059539880603551865
# Units: 200, Epochs: 130, Batch Size: 64, Validation Loss: 0.006130194757133722
# Units: 200, Epochs: 130, Batch Size: 128, Validation Loss: 0.006288871634751558
# Units: 200, Epochs: 150, Batch Size: 8, Validation Loss: 0.0059154755435884
# Units: 200, Epochs: 150, Batch Size: 16, Validation Loss: 0.006001337897032499
# Units: 200, Epochs: 150, Batch Size: 32, Validation Loss: 0.005955907516181469
# Units: 200, Epochs: 150, Batch Size: 64, Validation Loss: 0.005821811966598034
# Units: 200, Epochs: 150, Batch Size: 128, Validation Loss: 0.006378180347383022
# Units: 200, Epochs: 170, Batch Size: 8, Validation Loss: 0.005927916616201401
# Units: 200, Epochs: 170, Batch Size: 16, Validation Loss: 0.0060356855392456055
# Units: 200, Epochs: 170, Batch Size: 32, Validation Loss: 0.006011364981532097
# Units: 200, Epochs: 170, Batch Size: 64, Validation Loss: 0.005914620123803616
# Units: 200, Epochs: 170, Batch Size: 128, Validation Loss: 0.006274640094488859
# Units: 200, Epochs: 200, Batch Size: 8, Validation Loss: 0.0058433907106518745
# Units: 200, Epochs: 200, Batch Size: 16, Validation Loss: 0.005990898236632347
# Units: 200, Epochs: 200, Batch Size: 32, Validation Loss: 0.0059581114910542965
# Units: 200, Epochs: 200, Batch Size: 64, Validation Loss: 0.0059733460657298565
# Units: 200, Epochs: 200, Batch Size: 128, Validation Loss: 0.006438774988055229

# %%
import matplotlib.pyplot as plt
import numpy as np

# Misalkan 'history' adalah objek yang didapatkan setelah melatih model
train_loss = history.history['loss']
val_loss = history.history.get('val_loss')  # Jika validasi split digunakan

# Ubah list menjadi array NumPy
train_loss_np = np.array(train_loss)
val_loss_np = np.array(val_loss) if val_loss else None

# Siapkan plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot loss pelatihan
ax.plot(train_loss_np, label='Loss Pelatihan', linestyle='-', color='blue')

# Plot loss validasi (jika tersedia)
if val_loss_np is not None:
    ax.plot(val_loss_np, label='Loss Validasi', linestyle='--', color='orange')

# Label dan judul
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss Pelatihan dan Validasi')

# Legenda
ax.legend()

# Grid (opsional)
ax.grid(True)

# Tampilkan atau simpan plot
plt.show()  # atau plt.savefig('loss_curve.png')

#の説明 ada di komentar di bawah kode

# %%
model.summary()
# Out:
# Model: "sequential_399"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_798 (LSTM)             (None, 1, 200)            162400
#
#  lstm_799 (LSTM)             (None, 200)               320800
#
#  dense_399 (Dense)           (None, 1)                 201
#
# =================================================================
# Total params: 483,401
# Trainable params: 483,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# Simpan model dalam format .h5
model.save("modellag2robust.h5")

# Muat kembali model dari file .h5
#model = tf.keras.models.load_model("modelbener.h5")

# Gunakan model seperti yang Anda butuhkan

# %%
predictions = model.predict(testX)
predictions = scaler_harga.inverse_transform(predictions)
testY = scaler_harga.inverse_transform(testY)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
trainY = scaler_harga.inverse_transform(trainY)

# %%
df_test = pd.DataFrame({'Actual': np.squeeze(testY), 'Predicted': np.squeeze(predictions)})
df_test.head(30)
# Out:
#      Actual     Predicted
# 0   44250.0  50957.695312
# 1   43200.0  43352.882812
# 2   39000.0  42514.242188
# 3   34900.0  38762.777344
# 4   33900.0  34977.804688
# 5   34100.0  34134.011719
# 6   36400.0  34395.812500
# 7   36850.0  36506.964844
# 8   35400.0  36890.550781
# 9   35650.0  35276.609375
# 10  39250.0  35401.511719
# 11  43300.0  38673.546875
# 12  43550.0  42451.144531
# 13  42200.0  42683.097656
# 14  41450.0  41415.417969
# 15  43150.0  40544.996094
# 16  43100.0  42114.500000
# 17  49650.0  42117.773438
# 18  46600.0  48223.832031
# 19  42550.0  45324.429688
# 20  42250.0  41605.457031
# 21  43850.0  41275.242188
# 22  45250.0  42688.882812
# 23  38400.0  43919.570312
# 24  37000.0  38075.992188
# 25  51200.0  36901.730469
# 26  56550.0  49857.187500
# 27  48200.0  55199.636719
# 28  39000.0  47195.636719
# 29  43800.0  38497.058594

# %%
#df['Tanggal'] = pd.to_datetime(df['Tanggal'])
#df.set_index('Tanggal', inplace=True)
#df.sort_index(inplace=True)
#df.index = pd.to_datetime(df.index)

# %% [markdown]
# # Hasil Akhir

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error
from matplotlib.dates import MonthLocator, DateFormatter
mape = mean_absolute_percentage_error(testY, predictions)*100

plt.figure(figsize=(30, 10))
plt.plot(df.index[-len(testY):], testY, label='Testing', marker='', color='red', linestyle='-', linewidth=5)
plt.plot(df.index[-len(predictions):], predictions, label='Prediction', marker='', color='green', linestyle='-', linewidth=7)
plt.title(f'MAPE: {mape:.3f}%', fontsize=25)
plt.xlabel('Tanggal', fontsize=25)
plt.ylabel('Harga', fontsize=25)
plt.grid(True, linestyle='--', alpha=1)
plt.legend()

locator = MonthLocator(bymonth=[1, 7])
formatter = DateFormatter('%b %Y')
plt.gca().xaxis.set_major_locator(locator)
plt.gca().xaxis.set_major_formatter(formatter)
plt.xticks(rotation=0)
plt.show()
