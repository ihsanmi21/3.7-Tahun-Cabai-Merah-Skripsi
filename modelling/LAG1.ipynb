# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.dates as mdates
sns.set_style('whitegrid')
# %matplotlib inline
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, Dropout,GRU
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from tensorflow.keras import optimizers, Model
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Load Data

# %%
import os
CURR_FOLDER_PATH = os.getcwd()
BASE_PATH = os.path.dirname(os.path.dirname(CURR_FOLDER_PATH))
DATA_PATH = os.path.join(BASE_PATH, 'Lulus/data')

# %%
df = pd.read_excel(DATA_PATH + '/Hargalagpasartradisionallagvariable.xlsx')
# Data yang digunakan yaitu Harga cabai Rawit dan Harga Bawang putih sebagai Barang Subtitusi Sudah dilakukan lag - 1 Minggu

# %%
df
# Out:
#           Tanggal Harga Cabai Merah Harga Cabai Rawit
# 0    01/ 01/ 2018                 -                 -
# 1    08/ 01/ 2018             38300                 -
# 2    15/ 01/ 2018             42800             42600
# 3    22/ 01/ 2018             37850             42700
# 4    29/ 01/ 2018             38950             42600
# ..            ...               ...               ...
# 308  27/ 11/ 2023             80250             76600
# 309  04/ 12/ 2023             94900             79150
# 310  11/ 12/ 2023             99300             79100
# 311  18/ 12/ 2023             85000             75550
# 312  25/ 12/ 2023                 -             66350
#
# [313 rows x 3 columns]

# %% [markdown]
# # Statistical Analytics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tanggal            313 non-null    object
#  1   Harga Cabai Merah  313 non-null    object
#  2   Harga Cabai Rawit  313 non-null    object
# dtypes: object(3)
# memory usage: 7.5+ KB

# %%
df.shape
# Out:
# (313, 3)

# %%
df.replace('-', pd.NA, inplace=True)

# %%
missing_values = df.isnull().sum()
percentage_missing = (missing_values / df.shape[0]) * 100
print("Jumlah Missing Value per Kolom:")
print(missing_values)
print("\nPersentase Missing Value per Kolom:")
percentage_missing
# Out:
# Jumlah Missing Value per Kolom:
# Tanggal              0
# Harga Cabai Merah    9
# Harga Cabai Rawit    9
# dtype: int64
#
# Persentase Missing Value per Kolom:
# Tanggal              0.000000
# Harga Cabai Merah    2.875399
# Harga Cabai Rawit    2.875399
# dtype: float64

# %%
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/ %m/ %Y')
df['Bulan'] = df['Tanggal'].dt.to_period('M')
mean_values = df.groupby('Bulan').mean()


def fill_missing_with_mean(row):
    if pd.isna(row['Harga Cabai Merah']):
        row['Harga Cabai Merah'] = mean_values.loc[row['Bulan'], 'Harga Cabai Merah']
    if pd.isna(row['Harga Cabai Rawit']):
        row['Harga Cabai Rawit'] = mean_values.loc[row['Bulan'], 'Harga Cabai Rawit']
    return row


df = df.apply(fill_missing_with_mean, axis=1)
print(df)
# Out:
#        Tanggal  Harga Cabai Merah  Harga Cabai Rawit    Bulan
# 0   2018-01-01       39475.000000       42633.333333  2018-01
# 1   2018-01-08       38300.000000       42633.333333  2018-01
# 2   2018-01-15       42800.000000       42600.000000  2018-01
# 3   2018-01-22       37850.000000       42700.000000  2018-01
# 4   2018-01-29       38950.000000       42600.000000  2018-01
# ..         ...                ...                ...      ...
# 308 2023-11-27       80250.000000       76600.000000  2023-11
# 309 2023-12-04       94900.000000       79150.000000  2023-12
# 310 2023-12-11       99300.000000       79100.000000  2023-12
# 311 2023-12-18       85000.000000       75550.000000  2023-12
# 312 2023-12-25       93066.666667       66350.000000  2023-12
#
# [313 rows x 4 columns]

# %%
df['Harga Cabai Merah'] = df['Harga Cabai Merah'].astype('float64')
df['Harga Cabai Rawit'] = df['Harga Cabai Rawit'].astype('float64')

# %%
import seaborn as sns

harga_merah_stats = df['Harga Cabai Merah'].describe()
print("\nStatistik Deskriptif Harga Cabai Merah:")
print(harga_merah_stats)


harga_rawit_stats = df['Harga Cabai Rawit'].describe()
print("\nStatistik Deskriptif Harga Cabai Rawit:")
print(harga_rawit_stats)
# Out:
# Statistik Deskriptif Harga Cabai Merah:
# count       313.000000
# mean      43092.092652
# std       15493.651894
# min       21750.000000
# 25%       31650.000000
# 50%       40800.000000
# 75%       49550.000000
# max      109450.000000
# Name: Harga Cabai Merah, dtype: float64
#
# Statistik Deskriptif Harga Cabai Rawit:
# count       313.000000
# mean      44877.715655
# std       17241.023349
# min       22600.000000
# 25%       30950.000000
# 50%       42000.000000
# 75%       54250.000000
# max      100750.000000
# Name: Harga Cabai Rawit, dtype: float64

# %%
# Visualisasi
plt.figure(figsize=(25, 6))
plt.plot(df.index, df['Harga Cabai Merah'])
plt.title('Data Harga Cabai Merah 1 Januari 2018 - 31 Juli 2023')
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Merah')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Harga Cabai Merah'], kde=True)
plt.title('Distribusi Harga')
plt.xlabel('Harga Cabai Merah')
plt.ylabel('Frekuensi')
plt.show()

# %%
corr_with_target = df[['Harga Cabai Merah','Harga Cabai Rawit']].corr()
# Membuat heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr_with_target, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5,
                      annot_kws={"size": 25})  # Ukuran font diperbesar menjadi 25

# Memperbesar ukuran font label pada sumbu x dan y
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=20)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=20)

# Menambahkan judul
plt.title('Korelasi antara Harga Cabai Merah dan Barang Subtitusi', fontsize=16)

# Menampilkan heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
df.head()
sns.lmplot(x="Harga Cabai Merah", y="Harga Cabai Rawit", data=df)
plt.show()

# %%
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
sns.pairplot(df, diag_kind=None)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Ubah kolom 'Tanggal' menjadi tipe datetime dan tetapkan sebagai indeks
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/%m/%Y')
df.set_index('Tanggal', inplace=True)

# Melakukan dekomposisi musiman
decomposition = seasonal_decompose(df['Harga Cabai Merah'], model='additive')

# Menampilkan hasil
plt.figure(figsize=(15, 8))

# Data asli
plt.subplot(411)
plt.plot(df.index, df['Harga Cabai Merah'], label='Original')
plt.legend(loc='upper left')

# Trend
plt.subplot(412)
plt.plot(decomposition.trend.index, decomposition.trend, label='Trend')
plt.legend(loc='upper left')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing Data

# %%
scaler_rr = MinMaxScaler(feature_range=(0, 1))
scaler_harga = MinMaxScaler(feature_range=(0, 1))
df['Harga Cabai Merah_Scaled'] = scaler_harga.fit_transform(df[['Harga Cabai Merah']])
df['Harga Cabai Rawit_Scaled'] = scaler_rr.fit_transform(df[['Harga Cabai Rawit']])

# %%
df.head()
# Out:
#             Harga Cabai Merah  Harga Cabai Rawit    Bulan  \
# Tanggal
# 2018-01-01            39475.0       42633.333333  2018-01
# 2018-01-08            38300.0       42633.333333  2018-01
# 2018-01-15            42800.0       42600.000000  2018-01
# 2018-01-22            37850.0       42700.000000  2018-01
# 2018-01-29            38950.0       42600.000000  2018-01
#
#             Harga Cabai Merah_Scaled  Harga Cabai Rawit_Scaled
# Tanggal
# 2018-01-01                  0.202109                  0.256345
# 2018-01-08                  0.188712                  0.256345
# 2018-01-15                  0.240023                  0.255918
# 2018-01-22                  0.183580                  0.257198
# 2018-01-29                  0.196123                  0.255918

# %% [markdown]
# # Split Data

# %%
selected_columns = ['Harga Cabai Merah_Scaled','Harga Cabai Rawit_Scaled']
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)][selected_columns].values
        dataX.append(a)
        dataY.append(dataset[i + look_back:i + look_back + 1]['Harga Cabai Merah_Scaled'].values)
    return np.array(dataX), np.array(dataY)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], len(selected_columns)))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], len(selected_columns)))

# %% [markdown]
# # Pembuatan Model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(look_back, 2), activation='relu'))
model.add(LSTM(units=50, activation='relu'))
model.add(Dense(units=1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(trainX, trainY, epochs=110, batch_size=8, verbose=2,validation_split=0.2)
# Out:
# Epoch 1/110
# 25/25 - 2s - loss: 0.0474 - val_loss: 0.1419 - 2s/epoch - 96ms/step
# Epoch 2/110
# 25/25 - 0s - loss: 0.0289 - val_loss: 0.0883 - 78ms/epoch - 3ms/step
# Epoch 3/110
# 25/25 - 0s - loss: 0.0161 - val_loss: 0.0460 - 78ms/epoch - 3ms/step
# Epoch 4/110
# 25/25 - 0s - loss: 0.0137 - val_loss: 0.0371 - 77ms/epoch - 3ms/step
# Epoch 5/110
# 25/25 - 0s - loss: 0.0118 - val_loss: 0.0320 - 78ms/epoch - 3ms/step
# Epoch 6/110
# 25/25 - 0s - loss: 0.0101 - val_loss: 0.0213 - 77ms/epoch - 3ms/step
# Epoch 7/110
# 25/25 - 0s - loss: 0.0085 - val_loss: 0.0185 - 81ms/epoch - 3ms/step
# Epoch 8/110
# 25/25 - 0s - loss: 0.0076 - val_loss: 0.0146 - 78ms/epoch - 3ms/step
# Epoch 9/110
# 25/25 - 0s - loss: 0.0069 - val_loss: 0.0109 - 77ms/epoch - 3ms/step
# Epoch 10/110
# 25/25 - 0s - loss: 0.0066 - val_loss: 0.0096 - 81ms/epoch - 3ms/step
# Epoch 11/110
# 25/25 - 0s - loss: 0.0060 - val_loss: 0.0102 - 93ms/epoch - 4ms/step
# Epoch 12/110
# 25/25 - 0s - loss: 0.0055 - val_loss: 0.0099 - 85ms/epoch - 3ms/step
# Epoch 13/110
# 25/25 - 0s - loss: 0.0052 - val_loss: 0.0098 - 86ms/epoch - 3ms/step
# Epoch 14/110
# 25/25 - 0s - loss: 0.0048 - val_loss: 0.0078 - 75ms/epoch - 3ms/step
# Epoch 15/110
# 25/25 - 0s - loss: 0.0046 - val_loss: 0.0078 - 76ms/epoch - 3ms/step
# Epoch 16/110
# 25/25 - 0s - loss: 0.0045 - val_loss: 0.0074 - 88ms/epoch - 4ms/step
# Epoch 17/110
# 25/25 - 0s - loss: 0.0044 - val_loss: 0.0075 - 84ms/epoch - 3ms/step
# Epoch 18/110
# 25/25 - 0s - loss: 0.0042 - val_loss: 0.0074 - 82ms/epoch - 3ms/step
# Epoch 19/110
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0069 - 81ms/epoch - 3ms/step
# Epoch 20/110
# 25/25 - 0s - loss: 0.0044 - val_loss: 0.0068 - 81ms/epoch - 3ms/step
# Epoch 21/110
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0074 - 77ms/epoch - 3ms/step
# Epoch 22/110
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0069 - 75ms/epoch - 3ms/step
# Epoch 23/110
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0067 - 76ms/epoch - 3ms/step
# Epoch 24/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0073 - 76ms/epoch - 3ms/step
# Epoch 25/110
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0065 - 76ms/epoch - 3ms/step
# Epoch 26/110
# 25/25 - 0s - loss: 0.0041 - val_loss: 0.0064 - 76ms/epoch - 3ms/step
# Epoch 27/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0067 - 80ms/epoch - 3ms/step
# Epoch 28/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0065 - 74ms/epoch - 3ms/step
# Epoch 29/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0064 - 76ms/epoch - 3ms/step
# Epoch 30/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0063 - 75ms/epoch - 3ms/step
# Epoch 31/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0067 - 84ms/epoch - 3ms/step
# Epoch 32/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0067 - 93ms/epoch - 4ms/step
# Epoch 33/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0065 - 76ms/epoch - 3ms/step
# Epoch 34/110
# 25/25 - 0s - loss: 0.0042 - val_loss: 0.0076 - 76ms/epoch - 3ms/step
# Epoch 35/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0064 - 83ms/epoch - 3ms/step
# Epoch 36/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0065 - 83ms/epoch - 3ms/step
# Epoch 37/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0062 - 76ms/epoch - 3ms/step
# Epoch 38/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0059 - 74ms/epoch - 3ms/step
# Epoch 39/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0069 - 74ms/epoch - 3ms/step
# Epoch 40/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0059 - 75ms/epoch - 3ms/step
# Epoch 41/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0063 - 76ms/epoch - 3ms/step
# Epoch 42/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0063 - 75ms/epoch - 3ms/step
# Epoch 43/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0069 - 76ms/epoch - 3ms/step
# Epoch 44/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0060 - 76ms/epoch - 3ms/step
# Epoch 45/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0065 - 76ms/epoch - 3ms/step
# Epoch 46/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0059 - 136ms/epoch - 5ms/step
# Epoch 47/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0063 - 92ms/epoch - 4ms/step
# Epoch 48/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0059 - 82ms/epoch - 3ms/step
# Epoch 49/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0058 - 104ms/epoch - 4ms/step
# Epoch 50/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0065 - 87ms/epoch - 3ms/step
# Epoch 51/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0059 - 76ms/epoch - 3ms/step
# Epoch 52/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0067 - 80ms/epoch - 3ms/step
# Epoch 53/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0073 - 91ms/epoch - 4ms/step
# Epoch 54/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0079 - 92ms/epoch - 4ms/step
# Epoch 55/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0062 - 103ms/epoch - 4ms/step
# Epoch 56/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0058 - 98ms/epoch - 4ms/step
# Epoch 57/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0076 - 89ms/epoch - 4ms/step
# Epoch 58/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0070 - 90ms/epoch - 4ms/step
# Epoch 59/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0067 - 101ms/epoch - 4ms/step
# Epoch 60/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0061 - 90ms/epoch - 4ms/step
# Epoch 61/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0063 - 81ms/epoch - 3ms/step
# Epoch 62/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0066 - 79ms/epoch - 3ms/step
# Epoch 63/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0066 - 75ms/epoch - 3ms/step
# Epoch 64/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0076 - 77ms/epoch - 3ms/step
# Epoch 65/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0065 - 75ms/epoch - 3ms/step
# Epoch 66/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0077 - 74ms/epoch - 3ms/step
# Epoch 67/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0067 - 77ms/epoch - 3ms/step
# Epoch 68/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0077 - 151ms/epoch - 6ms/step
# Epoch 69/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0083 - 92ms/epoch - 4ms/step
# Epoch 70/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0058 - 81ms/epoch - 3ms/step
# Epoch 71/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0069 - 80ms/epoch - 3ms/step
# Epoch 72/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0063 - 102ms/epoch - 4ms/step
# Epoch 73/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0073 - 82ms/epoch - 3ms/step
# Epoch 74/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0063 - 83ms/epoch - 3ms/step
# Epoch 75/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0070 - 83ms/epoch - 3ms/step
# Epoch 76/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0061 - 74ms/epoch - 3ms/step
# Epoch 77/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0064 - 76ms/epoch - 3ms/step
# Epoch 78/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0072 - 76ms/epoch - 3ms/step
# Epoch 79/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0070 - 101ms/epoch - 4ms/step
# Epoch 80/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0059 - 88ms/epoch - 4ms/step
# Epoch 81/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0074 - 75ms/epoch - 3ms/step
# Epoch 82/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0069 - 79ms/epoch - 3ms/step
# Epoch 83/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0064 - 75ms/epoch - 3ms/step
# Epoch 84/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0066 - 76ms/epoch - 3ms/step
# Epoch 85/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0074 - 77ms/epoch - 3ms/step
# Epoch 86/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0066 - 76ms/epoch - 3ms/step
# Epoch 87/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0058 - 76ms/epoch - 3ms/step
# Epoch 88/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0067 - 148ms/epoch - 6ms/step
# Epoch 89/110
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0067 - 81ms/epoch - 3ms/step
# Epoch 90/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0062 - 75ms/epoch - 3ms/step
# Epoch 91/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0060 - 95ms/epoch - 4ms/step
# Epoch 92/110
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0068 - 77ms/epoch - 3ms/step
# Epoch 93/110
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0066 - 76ms/epoch - 3ms/step
# Epoch 94/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0064 - 76ms/epoch - 3ms/step
# Epoch 95/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0062 - 74ms/epoch - 3ms/step
# Epoch 96/110
# 25/25 - 0s - loss: 0.0040 - val_loss: 0.0086 - 80ms/epoch - 3ms/step
# Epoch 97/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0085 - 100ms/epoch - 4ms/step
# Epoch 98/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0068 - 85ms/epoch - 3ms/step
# Epoch 99/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0077 - 78ms/epoch - 3ms/step
# Epoch 100/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0073 - 85ms/epoch - 3ms/step
# Epoch 101/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0059 - 78ms/epoch - 3ms/step
# Epoch 102/110
# 25/25 - 0s - loss: 0.0039 - val_loss: 0.0068 - 76ms/epoch - 3ms/step
# Epoch 103/110
# 25/25 - 0s - loss: 0.0038 - val_loss: 0.0079 - 77ms/epoch - 3ms/step
# Epoch 104/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0073 - 76ms/epoch - 3ms/step
# Epoch 105/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0074 - 76ms/epoch - 3ms/step
# Epoch 106/110
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0066 - 77ms/epoch - 3ms/step
# Epoch 107/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0058 - 79ms/epoch - 3ms/step
# Epoch 108/110
# 25/25 - 0s - loss: 0.0037 - val_loss: 0.0066 - 77ms/epoch - 3ms/step
# Epoch 109/110
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0071 - 80ms/epoch - 3ms/step
# Epoch 110/110
# 25/25 - 0s - loss: 0.0036 - val_loss: 0.0061 - 78ms/epoch - 3ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Misalkan 'history' adalah objek yang didapatkan setelah melatih model
train_loss = history.history['loss']
val_loss = history.history.get('val_loss')  # Jika validasi split digunakan

# Ubah list menjadi array NumPy
train_loss_np = np.array(train_loss)
val_loss_np = np.array(val_loss) if val_loss else None

# Siapkan plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot loss pelatihan
ax.plot(train_loss_np, label='Loss Pelatihan', linestyle='-', color='blue')

# Plot loss validasi (jika tersedia)
if val_loss_np is not None:
    ax.plot(val_loss_np, label='Loss Validasi', linestyle='--', color='orange')

# Label dan judul
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss Pelatihan dan Validasi')

# Legenda
ax.legend()

# Grid (opsional)
ax.grid(True)

# Tampilkan atau simpan plot
plt.show()  # atau plt.savefig('loss_curve.png')

#の説明 ada di komentar di bawah kode

# %%
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 1, 50)             10600
#
#  lstm_31 (LSTM)              (None, 50)                20200
#
#  dense_15 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 30,851
# Trainable params: 30,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# Simpan model dalam format .h5
#model.save("modeltanptagantitestsudahvalidasi.h5")

# Muat kembali model dari file .h5
model = tf.keras.models.load_model("modeltanptagantitestsudahvalidasi.h5")

# Gunakan model seperti yang Anda butuhkan

# %%
predictions = model.predict(testX)
predictions = scaler_harga.inverse_transform(predictions)
testY = scaler_harga.inverse_transform(testY)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
trainY = scaler_harga.inverse_transform(trainY)

# %%
df_test = pd.DataFrame({'Actual': np.squeeze(testY), 'Predicted': np.squeeze(predictions)})
df_test.head(30)
# Out:
#      Actual     Predicted
# 0   44250.0  51499.628906
# 1   43200.0  44161.992188
# 2   39000.0  43316.613281
# 3   34900.0  39504.964844
# 4   33900.0  35742.406250
# 5   34100.0  34864.980469
# 6   36400.0  35027.132812
# 7   36850.0  37139.988281
# 8   35400.0  37390.992188
# 9   35650.0  35947.210938
# 10  39250.0  36148.117188
# 11  43300.0  39495.363281
# 12  43550.0  43423.695312
# 13  42200.0  43524.226562
# 14  41450.0  42132.078125
# 15  43150.0  41447.429688
# 16  43100.0  43029.980469
# 17  49650.0  42971.359375
# 18  46600.0  48860.027344
# 19  42550.0  46013.988281
# 20  42250.0  42478.910156
# 21  43850.0  42253.007812
# 22  45250.0  43644.296875
# 23  38400.0  44880.351562
# 24  37000.0  38911.980469
# 25  51200.0  37393.500000
# 26  56550.0  50475.453125
# 27  48200.0  55272.761719
# 28  39000.0  47693.406250
# 29  43800.0  39424.078125

# %%
#df['Tanggal'] = pd.to_datetime(df['Tanggal'])
#df.set_index('Tanggal', inplace=True)
#df.sort_index(inplace=True)
#df.index = pd.to_datetime(df.index)

# %% [markdown]
# # Hasil Akhir

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error
from matplotlib.dates import MonthLocator, DateFormatter
mape = mean_absolute_percentage_error(testY, predictions)*100

plt.figure(figsize=(30, 10))
plt.plot(df.index[:len(trainY)], trainY, label='Training', marker='', color='blue', linestyle='-', linewidth=5)
plt.plot(df.index[-len(testY):], testY, label='Testing', marker='', color='red', linestyle='-', linewidth=5)
plt.plot(df.index[-len(predictions):], predictions, label='Prediction', marker='', color='green', linestyle='-', linewidth=6)
plt.title(f'MAPE: {mape:.3f}%', fontsize=25)
plt.xlabel('Tanggal', fontsize=25)
plt.ylabel('Harga', fontsize=25)
plt.grid(True, linestyle='--', alpha=1)
plt.legend()

locator = MonthLocator(bymonth=[1, 7])
formatter = DateFormatter('%b %Y')
plt.gca().xaxis.set_major_locator(locator)
plt.gca().xaxis.set_major_formatter(formatter)
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error
from matplotlib.dates import MonthLocator, DateFormatter
mape = mean_absolute_percentage_error(testY, predictions)*100

plt.figure(figsize=(30, 10))
plt.plot(df.index[:len(trainY)], trainY, label='Training', marker='', color='blue', linestyle='-', linewidth=5)
plt.plot(df.index[-len(testY):], testY, label='Testing', marker='', color='red', linestyle='-', linewidth=5)
plt.plot(df.index[-len(predictions):], predictions, label='Prediction', marker='', color='green', linestyle='-', linewidth=6)
plt.title(f'MAPE: {mape:.3f}%', fontsize=25)
plt.xlabel('Tanggal', fontsize=25)
plt.ylabel('Harga', fontsize=25)
plt.grid(True, linestyle='--', alpha=1)
plt.legend()

locator = MonthLocator(bymonth=[1, 7])
formatter = DateFormatter('%b %Y')
plt.gca().xaxis.set_major_locator(locator)
plt.gca().xaxis.set_major_formatter(formatter)
plt.xticks(rotation=0)
plt.show()
