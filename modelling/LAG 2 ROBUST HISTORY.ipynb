# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.dates as mdates
sns.set_style('whitegrid')
# %matplotlib inline
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, Dropout,GRU
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from tensorflow.keras import optimizers, Model
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Load Data

# %%
import os
CURR_FOLDER_PATH = os.getcwd()
BASE_PATH = os.path.dirname(os.path.dirname(CURR_FOLDER_PATH))
DATA_PATH = os.path.join(BASE_PATH, 'Lulus/data')

# %%
df = pd.read_excel(DATA_PATH + '/Hargalagpasartradisionallagvariable.xlsx')
# Data yang digunakan yaitu Harga cabai Rawit dan Harga Bawang putih sebagai Barang Subtitusi Sudah dilakukan lag - 1 Minggu

# %%
df
# Out:
#           Tanggal Harga Cabai Merah Harga Cabai Rawit
# 0    01/ 01/ 2018                 -                 -
# 1    08/ 01/ 2018             38300                 -
# 2    15/ 01/ 2018             42800             42600
# 3    22/ 01/ 2018             37850             42700
# 4    29/ 01/ 2018             38950             42600
# ..            ...               ...               ...
# 308  27/ 11/ 2023             80250             76600
# 309  04/ 12/ 2023             94900             79150
# 310  11/ 12/ 2023             99300             79100
# 311  18/ 12/ 2023             85000             75550
# 312  25/ 12/ 2023                 -             66350
#
# [313 rows x 3 columns]

# %% [markdown]
# # Statistical Analytics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tanggal            313 non-null    object
#  1   Harga Cabai Merah  313 non-null    object
#  2   Harga Cabai Rawit  313 non-null    object
# dtypes: object(3)
# memory usage: 7.5+ KB

# %%
df.shape
# Out:
# (313, 3)

# %%
df.replace('-', pd.NA, inplace=True)

# %%
missing_values = df.isnull().sum()
percentage_missing = (missing_values / df.shape[0]) * 100
print("Jumlah Missing Value per Kolom:")
print(missing_values)
print("\nPersentase Missing Value per Kolom:")
percentage_missing
# Out:
# Jumlah Missing Value per Kolom:
# Tanggal              0
# Harga Cabai Merah    9
# Harga Cabai Rawit    9
# dtype: int64
#
# Persentase Missing Value per Kolom:
# Tanggal              0.000000
# Harga Cabai Merah    2.875399
# Harga Cabai Rawit    2.875399
# dtype: float64

# %%
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/ %m/ %Y')
df['Bulan'] = df['Tanggal'].dt.to_period('M')
mean_values = df.groupby('Bulan').mean()


def fill_missing_with_mean(row):
    if pd.isna(row['Harga Cabai Merah']):
        row['Harga Cabai Merah'] = mean_values.loc[row['Bulan'], 'Harga Cabai Merah']
    if pd.isna(row['Harga Cabai Rawit']):
        row['Harga Cabai Rawit'] = mean_values.loc[row['Bulan'], 'Harga Cabai Rawit']
    return row


df = df.apply(fill_missing_with_mean, axis=1)
print(df)
# Out:
#        Tanggal  Harga Cabai Merah  Harga Cabai Rawit    Bulan
# 0   2018-01-01       39475.000000       42633.333333  2018-01
# 1   2018-01-08       38300.000000       42633.333333  2018-01
# 2   2018-01-15       42800.000000       42600.000000  2018-01
# 3   2018-01-22       37850.000000       42700.000000  2018-01
# 4   2018-01-29       38950.000000       42600.000000  2018-01
# ..         ...                ...                ...      ...
# 308 2023-11-27       80250.000000       76600.000000  2023-11
# 309 2023-12-04       94900.000000       79150.000000  2023-12
# 310 2023-12-11       99300.000000       79100.000000  2023-12
# 311 2023-12-18       85000.000000       75550.000000  2023-12
# 312 2023-12-25       93066.666667       66350.000000  2023-12
#
# [313 rows x 4 columns]

# %%
df['Harga Cabai Merah'] = df['Harga Cabai Merah'].astype('float64')
df['Harga Cabai Rawit'] = df['Harga Cabai Rawit'].astype('float64')

# %%
import seaborn as sns

harga_merah_stats = df['Harga Cabai Merah'].describe()
print("\nStatistik Deskriptif Harga Cabai Merah:")
print(harga_merah_stats)


harga_rawit_stats = df['Harga Cabai Rawit'].describe()
print("\nStatistik Deskriptif Harga Cabai Rawit:")
print(harga_rawit_stats)
# Out:
# Statistik Deskriptif Harga Cabai Merah:
# count       313.000000
# mean      43092.092652
# std       15493.651894
# min       21750.000000
# 25%       31650.000000
# 50%       40800.000000
# 75%       49550.000000
# max      109450.000000
# Name: Harga Cabai Merah, dtype: float64
#
# Statistik Deskriptif Harga Cabai Rawit:
# count       313.000000
# mean      44877.715655
# std       17241.023349
# min       22600.000000
# 25%       30950.000000
# 50%       42000.000000
# 75%       54250.000000
# max      100750.000000
# Name: Harga Cabai Rawit, dtype: float64

# %%
# Visualisasi
plt.figure(figsize=(25, 6))
plt.plot(df.index, df['Harga Cabai Merah'])
plt.title('Data Harga Cabai Merah 1 Januari 2018 - 31 Juli 2023')
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Merah')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Harga Cabai Merah'], kde=True)
plt.title('Distribusi Harga')
plt.xlabel('Harga Cabai Merah')
plt.ylabel('Frekuensi')
plt.show()

# %%
corr_with_target = df[['Harga Cabai Merah','Harga Cabai Rawit']].corr()
# Membuat heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr_with_target, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5,
                      annot_kws={"size": 25})  # Ukuran font diperbesar menjadi 25

# Memperbesar ukuran font label pada sumbu x dan y
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=20)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=20)

# Menambahkan judul
plt.title('Korelasi antara Harga Cabai Merah dan Barang Subtitusi', fontsize=16)

# Menampilkan heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
df.head()
sns.lmplot(x="Harga Cabai Merah", y="Harga Cabai Rawit", data=df)
plt.show()

# %%
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
sns.pairplot(df, diag_kind=None)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Ubah kolom 'Tanggal' menjadi tipe datetime dan tetapkan sebagai indeks
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/%m/%Y')
df.set_index('Tanggal', inplace=True)

# Melakukan dekomposisi musiman
decomposition = seasonal_decompose(df['Harga Cabai Merah'], model='additive')

# Menampilkan hasil
plt.figure(figsize=(15, 8))

# Data asli
plt.subplot(411)
plt.plot(df.index, df['Harga Cabai Merah'], label='Original')
plt.legend(loc='upper left')

# Trend
plt.subplot(412)
plt.plot(decomposition.trend.index, decomposition.trend, label='Trend')
plt.legend(loc='upper left')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing Data

# %%
scaler_rr = MinMaxScaler(feature_range=(0, 1))
scaler_harga = MinMaxScaler(feature_range=(0, 1))
df['Harga Cabai Merah_Scaled'] = scaler_harga.fit_transform(df[['Harga Cabai Merah']])
df['Harga Cabai Rawit_Scaled'] = scaler_rr.fit_transform(df[['Harga Cabai Rawit']])

# %%
df.head()
# Out:
#             Harga Cabai Merah  Harga Cabai Rawit    Bulan  \
# Tanggal
# 2018-01-01            39475.0       42633.333333  2018-01
# 2018-01-08            38300.0       42633.333333  2018-01
# 2018-01-15            42800.0       42600.000000  2018-01
# 2018-01-22            37850.0       42700.000000  2018-01
# 2018-01-29            38950.0       42600.000000  2018-01
#
#             Harga Cabai Merah_Scaled  Harga Cabai Rawit_Scaled
# Tanggal
# 2018-01-01                  0.202109                  0.256345
# 2018-01-08                  0.188712                  0.256345
# 2018-01-15                  0.240023                  0.255918
# 2018-01-22                  0.183580                  0.257198
# 2018-01-29                  0.196123                  0.255918

# %% [markdown]
# # Split Data

# %%
from sklearn.model_selection import train_test_split

selected_columns = ['Harga Cabai Merah_Scaled', 'Harga Cabai Rawit_Scaled']
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)][selected_columns].values
        dataX.append(a)
        dataY.append(dataset[i + look_back:i + look_back + 1]['Harga Cabai Merah_Scaled'].values)
    return np.array(dataX), np.array(dataY)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Memisahkan 20% data latih sebagai data validasi tanpa mengacak urutan waktu
trainX, valX, trainY, valY = train_test_split(trainX, trainY, test_size=0.2, shuffle=False)

print("Ukuran data latih setelah pembagian:", trainX.shape)
print("Ukuran data validasi setelah pembagian:", valX.shape)
print("Ukuran data uji:", testX.shape)
# Out:
# Ukuran data latih setelah pembagian: (199, 1, 2)
# Ukuran data validasi setelah pembagian: (50, 1, 2)
# Ukuran data uji: (62, 1, 2)

# %% [markdown]
# # Pembuatan Model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# List parameter yang akan diuji
units_list = [10, 30, 50, 70, 90, 110, 130, 150, 170, 200]
epochs_list = [50, 70, 90, 110, 130, 150, 170, 200]
batch_size_list = [8, 16, 32, 64, 128]

# Loop untuk mencoba semua kombinasi parameter
for units in units_list:
    for epochs in epochs_list:
        for batch_size in batch_size_list:
            # Membuat model
            model = Sequential()
            model.add(LSTM(units=units, return_sequences=True, input_shape=(look_back, 2), activation='relu'))
            model.add(LSTM(units=units, activation='relu'))
            model.add(Dense(units=1, activation='linear'))
            model.compile(optimizer='adam', loss='mean_squared_error')
            # Melatih model dengan validation_data
            history = model.fit(trainX, trainY, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=(valX, valY))
            # Mendapatkan validation loss
            val_loss = np.min(history.history['val_loss'])
            # Mencetak hasil
            print(f"Units: {units}, Epochs: {epochs}, Batch Size: {batch_size}, Validation Loss: {val_loss}")
# Out:
# Units: 10, Epochs: 50, Batch Size: 8, Validation Loss: 0.011313077993690968
# Units: 10, Epochs: 50, Batch Size: 16, Validation Loss: 0.011464148759841919
# Units: 10, Epochs: 50, Batch Size: 32, Validation Loss: 0.027910882607102394
# Units: 10, Epochs: 50, Batch Size: 64, Validation Loss: 0.05508919060230255
# Units: 10, Epochs: 50, Batch Size: 128, Validation Loss: 0.10168125480413437
# Units: 10, Epochs: 70, Batch Size: 8, Validation Loss: 0.011035719886422157
# Units: 10, Epochs: 70, Batch Size: 16, Validation Loss: 0.011350180022418499
# Units: 10, Epochs: 70, Batch Size: 32, Validation Loss: 0.013093123212456703
# Units: 10, Epochs: 70, Batch Size: 64, Validation Loss: 0.012215651571750641
# Units: 10, Epochs: 70, Batch Size: 128, Validation Loss: 0.047730568796396255
# Units: 10, Epochs: 90, Batch Size: 8, Validation Loss: 0.007822781801223755
# Units: 10, Epochs: 90, Batch Size: 16, Validation Loss: 0.01238605659455061
# Units: 10, Epochs: 90, Batch Size: 32, Validation Loss: 0.013314779847860336
# Units: 10, Epochs: 90, Batch Size: 64, Validation Loss: 0.015217406675219536
# Units: 10, Epochs: 90, Batch Size: 128, Validation Loss: 0.04970397427678108
# Units: 10, Epochs: 110, Batch Size: 8, Validation Loss: 0.009101099334657192
# Units: 10, Epochs: 110, Batch Size: 16, Validation Loss: 0.009445800445973873
# Units: 10, Epochs: 110, Batch Size: 32, Validation Loss: 0.007379403803497553
# Units: 10, Epochs: 110, Batch Size: 64, Validation Loss: 0.012237437069416046
# Units: 10, Epochs: 110, Batch Size: 128, Validation Loss: 0.02256116084754467
# Units: 10, Epochs: 130, Batch Size: 8, Validation Loss: 0.005968266632407904
# Units: 10, Epochs: 130, Batch Size: 16, Validation Loss: 0.0063524795696139336
# Units: 10, Epochs: 130, Batch Size: 32, Validation Loss: 0.011898182332515717
# Units: 10, Epochs: 130, Batch Size: 64, Validation Loss: 0.01085780281573534
# Units: 10, Epochs: 130, Batch Size: 128, Validation Loss: 0.019356882199645042
# Units: 10, Epochs: 150, Batch Size: 8, Validation Loss: 0.007855289615690708
# Units: 10, Epochs: 150, Batch Size: 16, Validation Loss: 0.0083610899746418
# Units: 10, Epochs: 150, Batch Size: 32, Validation Loss: 0.010921287350356579
# Units: 10, Epochs: 150, Batch Size: 64, Validation Loss: 0.00589005509391427
# Units: 10, Epochs: 150, Batch Size: 128, Validation Loss: 0.01376727782189846
# Units: 10, Epochs: 170, Batch Size: 8, Validation Loss: 0.006083418149501085
# Units: 10, Epochs: 170, Batch Size: 16, Validation Loss: 0.007129659876227379
# Units: 10, Epochs: 170, Batch Size: 32, Validation Loss: 0.008910834789276123
# Units: 10, Epochs: 170, Batch Size: 64, Validation Loss: 0.009820814244449139
# Units: 10, Epochs: 170, Batch Size: 128, Validation Loss: 0.014573709107935429
# Units: 10, Epochs: 200, Batch Size: 8, Validation Loss: 0.006220694165676832
# Units: 10, Epochs: 200, Batch Size: 16, Validation Loss: 0.008422589860856533
# Units: 10, Epochs: 200, Batch Size: 32, Validation Loss: 0.007384552154690027
# Units: 10, Epochs: 200, Batch Size: 64, Validation Loss: 0.011973116546869278
# Units: 10, Epochs: 200, Batch Size: 128, Validation Loss: 0.016394570469856262
# Units: 30, Epochs: 50, Batch Size: 8, Validation Loss: 0.008125962689518929
# Units: 30, Epochs: 50, Batch Size: 16, Validation Loss: 0.011585662141442299
# Units: 30, Epochs: 50, Batch Size: 32, Validation Loss: 0.00934448279440403
# Units: 30, Epochs: 50, Batch Size: 64, Validation Loss: 0.019588802009820938
# Units: 30, Epochs: 50, Batch Size: 128, Validation Loss: 0.03786243498325348
# Units: 30, Epochs: 70, Batch Size: 8, Validation Loss: 0.006742554251104593
# Units: 30, Epochs: 70, Batch Size: 16, Validation Loss: 0.00817206222563982
# Units: 30, Epochs: 70, Batch Size: 32, Validation Loss: 0.00954192504286766
# Units: 30, Epochs: 70, Batch Size: 64, Validation Loss: 0.01404894981533289
# Units: 30, Epochs: 70, Batch Size: 128, Validation Loss: 0.025440940633416176
# Units: 30, Epochs: 90, Batch Size: 8, Validation Loss: 0.005886146333068609
# Units: 30, Epochs: 90, Batch Size: 16, Validation Loss: 0.007888317108154297
# Units: 30, Epochs: 90, Batch Size: 32, Validation Loss: 0.00948747806251049
# Units: 30, Epochs: 90, Batch Size: 64, Validation Loss: 0.009884323924779892
# Units: 30, Epochs: 90, Batch Size: 128, Validation Loss: 0.014816176146268845
# Units: 30, Epochs: 110, Batch Size: 8, Validation Loss: 0.006216174457222223
# Units: 30, Epochs: 110, Batch Size: 16, Validation Loss: 0.006083199288696051
# Units: 30, Epochs: 110, Batch Size: 32, Validation Loss: 0.00775701180100441
# Units: 30, Epochs: 110, Batch Size: 64, Validation Loss: 0.007040444761514664
# Units: 30, Epochs: 110, Batch Size: 128, Validation Loss: 0.01589394547045231
# Units: 30, Epochs: 130, Batch Size: 8, Validation Loss: 0.005703976843506098
# Units: 30, Epochs: 130, Batch Size: 16, Validation Loss: 0.007205571513622999
# Units: 30, Epochs: 130, Batch Size: 32, Validation Loss: 0.006462157238274813
# Units: 30, Epochs: 130, Batch Size: 64, Validation Loss: 0.00902577955275774
# Units: 30, Epochs: 130, Batch Size: 128, Validation Loss: 0.01105300523340702
# Units: 30, Epochs: 150, Batch Size: 8, Validation Loss: 0.00575811043381691
# Units: 30, Epochs: 150, Batch Size: 16, Validation Loss: 0.00634123757481575
# Units: 30, Epochs: 150, Batch Size: 32, Validation Loss: 0.006513770204037428
# Units: 30, Epochs: 150, Batch Size: 64, Validation Loss: 0.010405751876533031
# Units: 30, Epochs: 150, Batch Size: 128, Validation Loss: 0.00948130339384079
# Units: 30, Epochs: 170, Batch Size: 8, Validation Loss: 0.005870482884347439
# Units: 30, Epochs: 170, Batch Size: 16, Validation Loss: 0.0063402606174349785
# Units: 30, Epochs: 170, Batch Size: 32, Validation Loss: 0.006532824132591486
# Units: 30, Epochs: 170, Batch Size: 64, Validation Loss: 0.00585222477093339
# Units: 30, Epochs: 170, Batch Size: 128, Validation Loss: 0.00902401003986597
# Units: 30, Epochs: 200, Batch Size: 8, Validation Loss: 0.006317567080259323
# Units: 30, Epochs: 200, Batch Size: 16, Validation Loss: 0.0059886230155825615
# Units: 30, Epochs: 200, Batch Size: 32, Validation Loss: 0.006226062774658203
# Units: 30, Epochs: 200, Batch Size: 64, Validation Loss: 0.005936380475759506
# Units: 30, Epochs: 200, Batch Size: 128, Validation Loss: 0.009175091981887817
# Units: 50, Epochs: 50, Batch Size: 8, Validation Loss: 0.006258813198655844
# Units: 50, Epochs: 50, Batch Size: 16, Validation Loss: 0.007290370296686888
# Units: 50, Epochs: 50, Batch Size: 32, Validation Loss: 0.00965968705713749
# Units: 50, Epochs: 50, Batch Size: 64, Validation Loss: 0.013792871497571468
# Units: 50, Epochs: 50, Batch Size: 128, Validation Loss: 0.028213031589984894
# Units: 50, Epochs: 70, Batch Size: 8, Validation Loss: 0.0061673326417803764
# Units: 50, Epochs: 70, Batch Size: 16, Validation Loss: 0.006176586262881756
# Units: 50, Epochs: 70, Batch Size: 32, Validation Loss: 0.008566703647375107
# Units: 50, Epochs: 70, Batch Size: 64, Validation Loss: 0.00862934160977602
# Units: 50, Epochs: 70, Batch Size: 128, Validation Loss: 0.019143613055348396
# Units: 50, Epochs: 90, Batch Size: 8, Validation Loss: 0.005963086616247892
# Units: 50, Epochs: 90, Batch Size: 16, Validation Loss: 0.006205106154084206
# Units: 50, Epochs: 90, Batch Size: 32, Validation Loss: 0.0077385809272527695
# Units: 50, Epochs: 90, Batch Size: 64, Validation Loss: 0.008731309324502945
# Units: 50, Epochs: 90, Batch Size: 128, Validation Loss: 0.013541480526328087
# Units: 50, Epochs: 110, Batch Size: 8, Validation Loss: 0.005892366170883179
# Units: 50, Epochs: 110, Batch Size: 16, Validation Loss: 0.006601762026548386
# Units: 50, Epochs: 110, Batch Size: 32, Validation Loss: 0.006609013304114342
# Units: 50, Epochs: 110, Batch Size: 64, Validation Loss: 0.008401934057474136
# Units: 50, Epochs: 110, Batch Size: 128, Validation Loss: 0.0099424347281456
# Units: 50, Epochs: 130, Batch Size: 8, Validation Loss: 0.00580285768955946
# Units: 50, Epochs: 130, Batch Size: 16, Validation Loss: 0.006301554385572672
# Units: 50, Epochs: 130, Batch Size: 32, Validation Loss: 0.006627731490880251
# Units: 50, Epochs: 130, Batch Size: 64, Validation Loss: 0.008132020942866802
# Units: 50, Epochs: 130, Batch Size: 128, Validation Loss: 0.007547754794359207
# Units: 50, Epochs: 150, Batch Size: 8, Validation Loss: 0.006197022739797831
# Units: 50, Epochs: 150, Batch Size: 16, Validation Loss: 0.006327119655907154
# Units: 50, Epochs: 150, Batch Size: 32, Validation Loss: 0.006274582352489233
# Units: 50, Epochs: 150, Batch Size: 64, Validation Loss: 0.008124102838337421
# Units: 50, Epochs: 150, Batch Size: 128, Validation Loss: 0.00845571979880333
# Units: 50, Epochs: 170, Batch Size: 8, Validation Loss: 0.005799260921776295
# Units: 50, Epochs: 170, Batch Size: 16, Validation Loss: 0.006317043211311102
# Units: 50, Epochs: 170, Batch Size: 32, Validation Loss: 0.006825458258390427
# Units: 50, Epochs: 170, Batch Size: 64, Validation Loss: 0.006959052290767431
# Units: 50, Epochs: 170, Batch Size: 128, Validation Loss: 0.008261878043413162
# Units: 50, Epochs: 200, Batch Size: 8, Validation Loss: 0.005828352645039558
# Units: 50, Epochs: 200, Batch Size: 16, Validation Loss: 0.006147740408778191
# Units: 50, Epochs: 200, Batch Size: 32, Validation Loss: 0.006000943016260862
# Units: 50, Epochs: 200, Batch Size: 64, Validation Loss: 0.007415763568133116
# Units: 50, Epochs: 200, Batch Size: 128, Validation Loss: 0.0063671208918094635
# Units: 70, Epochs: 50, Batch Size: 8, Validation Loss: 0.006006638519465923
# Units: 70, Epochs: 50, Batch Size: 16, Validation Loss: 0.007148039527237415
# Units: 70, Epochs: 50, Batch Size: 32, Validation Loss: 0.009449314326047897
# Units: 70, Epochs: 50, Batch Size: 64, Validation Loss: 0.009767607785761356
# Units: 70, Epochs: 50, Batch Size: 128, Validation Loss: 0.027085766196250916
# Units: 70, Epochs: 70, Batch Size: 8, Validation Loss: 0.006464418955147266
# Units: 70, Epochs: 70, Batch Size: 16, Validation Loss: 0.006268558092415333
# Units: 70, Epochs: 70, Batch Size: 32, Validation Loss: 0.007809700910001993
# Units: 70, Epochs: 70, Batch Size: 64, Validation Loss: 0.007190737873315811
# Units: 70, Epochs: 70, Batch Size: 128, Validation Loss: 0.011166973039507866
# Units: 70, Epochs: 90, Batch Size: 8, Validation Loss: 0.005962283816188574
# Units: 70, Epochs: 90, Batch Size: 16, Validation Loss: 0.006238871719688177
# Units: 70, Epochs: 90, Batch Size: 32, Validation Loss: 0.006515068467706442
# Units: 70, Epochs: 90, Batch Size: 64, Validation Loss: 0.0065471637062728405
# Units: 70, Epochs: 90, Batch Size: 128, Validation Loss: 0.00959058664739132
# Units: 70, Epochs: 110, Batch Size: 8, Validation Loss: 0.0060793813318014145
# Units: 70, Epochs: 110, Batch Size: 16, Validation Loss: 0.0061440421268343925
# Units: 70, Epochs: 110, Batch Size: 32, Validation Loss: 0.006510159932076931
# Units: 70, Epochs: 110, Batch Size: 64, Validation Loss: 0.007876250892877579
# Units: 70, Epochs: 110, Batch Size: 128, Validation Loss: 0.008399681188166142
# Units: 70, Epochs: 130, Batch Size: 8, Validation Loss: 0.0057946848683059216
# Units: 70, Epochs: 130, Batch Size: 16, Validation Loss: 0.006048435345292091
# Units: 70, Epochs: 130, Batch Size: 32, Validation Loss: 0.006475187372416258
# Units: 70, Epochs: 130, Batch Size: 64, Validation Loss: 0.00802220031619072
# Units: 70, Epochs: 130, Batch Size: 128, Validation Loss: 0.008604568429291248
# Units: 70, Epochs: 150, Batch Size: 8, Validation Loss: 0.005884391721338034
# Units: 70, Epochs: 150, Batch Size: 16, Validation Loss: 0.0060607027262449265
# Units: 70, Epochs: 150, Batch Size: 32, Validation Loss: 0.0060309916734695435
# Units: 70, Epochs: 150, Batch Size: 64, Validation Loss: 0.006598487496376038
# Units: 70, Epochs: 150, Batch Size: 128, Validation Loss: 0.008577149361371994
# Units: 70, Epochs: 170, Batch Size: 8, Validation Loss: 0.005792551673948765
# Units: 70, Epochs: 170, Batch Size: 16, Validation Loss: 0.006142479367554188
# Units: 70, Epochs: 170, Batch Size: 32, Validation Loss: 0.006082084029912949
# Units: 70, Epochs: 170, Batch Size: 64, Validation Loss: 0.006933250930160284
# Units: 70, Epochs: 170, Batch Size: 128, Validation Loss: 0.007177744992077351
# Units: 70, Epochs: 200, Batch Size: 8, Validation Loss: 0.005861581768840551
# Units: 70, Epochs: 200, Batch Size: 16, Validation Loss: 0.006221556570380926
# Units: 70, Epochs: 200, Batch Size: 32, Validation Loss: 0.005965550430119038
# Units: 70, Epochs: 200, Batch Size: 64, Validation Loss: 0.006512208376079798
# Units: 70, Epochs: 200, Batch Size: 128, Validation Loss: 0.006422516889870167
# Units: 90, Epochs: 50, Batch Size: 8, Validation Loss: 0.005873405374586582
# Units: 90, Epochs: 50, Batch Size: 16, Validation Loss: 0.007023686543107033
# Units: 90, Epochs: 50, Batch Size: 32, Validation Loss: 0.007852108217775822
# Units: 90, Epochs: 50, Batch Size: 64, Validation Loss: 0.00794418528676033
# Units: 90, Epochs: 50, Batch Size: 128, Validation Loss: 0.024312522262334824
# Units: 90, Epochs: 70, Batch Size: 8, Validation Loss: 0.006003060843795538
# Units: 90, Epochs: 70, Batch Size: 16, Validation Loss: 0.006313182879239321
# Units: 90, Epochs: 70, Batch Size: 32, Validation Loss: 0.006760315503925085
# Units: 90, Epochs: 70, Batch Size: 64, Validation Loss: 0.007800890598446131
# Units: 90, Epochs: 70, Batch Size: 128, Validation Loss: 0.009610021486878395
# Units: 90, Epochs: 90, Batch Size: 8, Validation Loss: 0.005818279925733805
# Units: 90, Epochs: 90, Batch Size: 16, Validation Loss: 0.005909694824367762
# Units: 90, Epochs: 90, Batch Size: 32, Validation Loss: 0.006617077626287937
# Units: 90, Epochs: 90, Batch Size: 64, Validation Loss: 0.007345537655055523
# Units: 90, Epochs: 90, Batch Size: 128, Validation Loss: 0.007793213706463575
# Units: 90, Epochs: 110, Batch Size: 8, Validation Loss: 0.005917457863688469
# Units: 90, Epochs: 110, Batch Size: 16, Validation Loss: 0.005970530677586794
# Units: 90, Epochs: 110, Batch Size: 32, Validation Loss: 0.0063162147998809814
# Units: 90, Epochs: 110, Batch Size: 64, Validation Loss: 0.007967155426740646
# Units: 90, Epochs: 110, Batch Size: 128, Validation Loss: 0.008242620155215263
# Units: 90, Epochs: 130, Batch Size: 8, Validation Loss: 0.005766859278082848
# Units: 90, Epochs: 130, Batch Size: 16, Validation Loss: 0.006338819861412048
# Units: 90, Epochs: 130, Batch Size: 32, Validation Loss: 0.0061622681096196175
# Units: 90, Epochs: 130, Batch Size: 64, Validation Loss: 0.006260271649807692
# Units: 90, Epochs: 130, Batch Size: 128, Validation Loss: 0.008259529247879982
# Units: 90, Epochs: 150, Batch Size: 8, Validation Loss: 0.00576469162479043
# Units: 90, Epochs: 150, Batch Size: 16, Validation Loss: 0.006361378822475672
# Units: 90, Epochs: 150, Batch Size: 32, Validation Loss: 0.0059186541475355625
# Units: 90, Epochs: 150, Batch Size: 64, Validation Loss: 0.006459257565438747
# Units: 90, Epochs: 150, Batch Size: 128, Validation Loss: 0.007347956765443087
# Units: 90, Epochs: 170, Batch Size: 8, Validation Loss: 0.005944231525063515
# Units: 90, Epochs: 170, Batch Size: 16, Validation Loss: 0.005721426103264093
# Units: 90, Epochs: 170, Batch Size: 32, Validation Loss: 0.006056908518075943
# Units: 90, Epochs: 170, Batch Size: 64, Validation Loss: 0.0062682367861270905
# Units: 90, Epochs: 170, Batch Size: 128, Validation Loss: 0.00683211674913764
# Units: 90, Epochs: 200, Batch Size: 8, Validation Loss: 0.005840348545461893
# Units: 90, Epochs: 200, Batch Size: 16, Validation Loss: 0.006289309822022915
# Units: 90, Epochs: 200, Batch Size: 32, Validation Loss: 0.006176286842674017
# Units: 90, Epochs: 200, Batch Size: 64, Validation Loss: 0.006040958687663078
# Units: 90, Epochs: 200, Batch Size: 128, Validation Loss: 0.006153820548206568
# Units: 110, Epochs: 50, Batch Size: 8, Validation Loss: 0.00621523754671216
# Units: 110, Epochs: 50, Batch Size: 16, Validation Loss: 0.006483153905719519
# Units: 110, Epochs: 50, Batch Size: 32, Validation Loss: 0.006704410538077354
# Units: 110, Epochs: 50, Batch Size: 64, Validation Loss: 0.009559385478496552
# Units: 110, Epochs: 50, Batch Size: 128, Validation Loss: 0.016997620463371277
# Units: 110, Epochs: 70, Batch Size: 8, Validation Loss: 0.005766423884779215
# Units: 110, Epochs: 70, Batch Size: 16, Validation Loss: 0.006227706093341112
# Units: 110, Epochs: 70, Batch Size: 32, Validation Loss: 0.006600092630833387
# Units: 110, Epochs: 70, Batch Size: 64, Validation Loss: 0.007043375167995691
# Units: 110, Epochs: 70, Batch Size: 128, Validation Loss: 0.010175780393183231
# Units: 110, Epochs: 90, Batch Size: 8, Validation Loss: 0.005808081477880478
# Units: 110, Epochs: 90, Batch Size: 16, Validation Loss: 0.006342427339404821
# Units: 110, Epochs: 90, Batch Size: 32, Validation Loss: 0.006201956886798143
# Units: 110, Epochs: 90, Batch Size: 64, Validation Loss: 0.007018770556896925
# Units: 110, Epochs: 90, Batch Size: 128, Validation Loss: 0.00882594846189022
# Units: 110, Epochs: 110, Batch Size: 8, Validation Loss: 0.005860045552253723
# Units: 110, Epochs: 110, Batch Size: 16, Validation Loss: 0.006003796588629484
# Units: 110, Epochs: 110, Batch Size: 32, Validation Loss: 0.0061496258713305
# Units: 110, Epochs: 110, Batch Size: 64, Validation Loss: 0.0069601391442120075
# Units: 110, Epochs: 110, Batch Size: 128, Validation Loss: 0.006943343672901392
# Units: 110, Epochs: 130, Batch Size: 8, Validation Loss: 0.005936841946095228
# Units: 110, Epochs: 130, Batch Size: 16, Validation Loss: 0.006307367235422134
# Units: 110, Epochs: 130, Batch Size: 32, Validation Loss: 0.0059275696985423565
# Units: 110, Epochs: 130, Batch Size: 64, Validation Loss: 0.0065381391905248165
# Units: 110, Epochs: 130, Batch Size: 128, Validation Loss: 0.0067123230546712875
# Units: 110, Epochs: 150, Batch Size: 8, Validation Loss: 0.00580582907423377
# Units: 110, Epochs: 150, Batch Size: 16, Validation Loss: 0.005922090262174606
# Units: 110, Epochs: 150, Batch Size: 32, Validation Loss: 0.005719042848795652
# Units: 110, Epochs: 150, Batch Size: 64, Validation Loss: 0.0062642465345561504
# Units: 110, Epochs: 150, Batch Size: 128, Validation Loss: 0.007720339111983776
# Units: 110, Epochs: 170, Batch Size: 8, Validation Loss: 0.005970318801701069
# Units: 110, Epochs: 170, Batch Size: 16, Validation Loss: 0.0062543670646846294
# Units: 110, Epochs: 170, Batch Size: 32, Validation Loss: 0.006099898833781481
# Units: 110, Epochs: 170, Batch Size: 64, Validation Loss: 0.0062002562917768955
# Units: 110, Epochs: 170, Batch Size: 128, Validation Loss: 0.006420882884413004
# Units: 110, Epochs: 200, Batch Size: 8, Validation Loss: 0.0058645037934184074
# Units: 110, Epochs: 200, Batch Size: 16, Validation Loss: 0.006188667844980955
# Units: 110, Epochs: 200, Batch Size: 32, Validation Loss: 0.005853488575667143
# Units: 110, Epochs: 200, Batch Size: 64, Validation Loss: 0.005921300500631332
# Units: 110, Epochs: 200, Batch Size: 128, Validation Loss: 0.006476365961134434
# Units: 130, Epochs: 50, Batch Size: 8, Validation Loss: 0.005882346536964178
# Units: 130, Epochs: 50, Batch Size: 16, Validation Loss: 0.006243143696337938
# Units: 130, Epochs: 50, Batch Size: 32, Validation Loss: 0.0064208609983325005
# Units: 130, Epochs: 50, Batch Size: 64, Validation Loss: 0.007643477525562048
# Units: 130, Epochs: 50, Batch Size: 128, Validation Loss: 0.014903276227414608
# Units: 130, Epochs: 70, Batch Size: 8, Validation Loss: 0.005899965297430754
# Units: 130, Epochs: 70, Batch Size: 16, Validation Loss: 0.006242811214178801
# Units: 130, Epochs: 70, Batch Size: 32, Validation Loss: 0.006100000347942114
# Units: 130, Epochs: 70, Batch Size: 64, Validation Loss: 0.007222822401672602
# Units: 130, Epochs: 70, Batch Size: 128, Validation Loss: 0.008841145783662796
# Units: 130, Epochs: 90, Batch Size: 8, Validation Loss: 0.006084701977670193
# Units: 130, Epochs: 90, Batch Size: 16, Validation Loss: 0.0061895959079265594
# Units: 130, Epochs: 90, Batch Size: 32, Validation Loss: 0.006335398182272911
# Units: 130, Epochs: 90, Batch Size: 64, Validation Loss: 0.007001740392297506
# Units: 130, Epochs: 90, Batch Size: 128, Validation Loss: 0.007734683342278004
# Units: 130, Epochs: 110, Batch Size: 8, Validation Loss: 0.005971169099211693
# Units: 130, Epochs: 110, Batch Size: 16, Validation Loss: 0.006019285414367914
# Units: 130, Epochs: 110, Batch Size: 32, Validation Loss: 0.006189568433910608
# Units: 130, Epochs: 110, Batch Size: 64, Validation Loss: 0.006289226468652487
# Units: 130, Epochs: 110, Batch Size: 128, Validation Loss: 0.006812504958361387
# Units: 130, Epochs: 130, Batch Size: 8, Validation Loss: 0.0058919028379023075
# Units: 130, Epochs: 130, Batch Size: 16, Validation Loss: 0.0061514959670603275
# Units: 130, Epochs: 130, Batch Size: 32, Validation Loss: 0.005856141448020935
# Units: 130, Epochs: 130, Batch Size: 64, Validation Loss: 0.006177478935569525
# Units: 130, Epochs: 130, Batch Size: 128, Validation Loss: 0.006916720885783434
# Units: 130, Epochs: 150, Batch Size: 8, Validation Loss: 0.006017917301505804
# Units: 130, Epochs: 150, Batch Size: 16, Validation Loss: 0.005981098860502243
# Units: 130, Epochs: 150, Batch Size: 32, Validation Loss: 0.005937507376074791
# Units: 130, Epochs: 150, Batch Size: 64, Validation Loss: 0.0061798095703125
# Units: 130, Epochs: 150, Batch Size: 128, Validation Loss: 0.006740035023540258
# Units: 130, Epochs: 170, Batch Size: 8, Validation Loss: 0.005835394375026226
# Units: 130, Epochs: 170, Batch Size: 16, Validation Loss: 0.00605707336217165
# Units: 130, Epochs: 170, Batch Size: 32, Validation Loss: 0.0057552773505449295
# Units: 130, Epochs: 170, Batch Size: 64, Validation Loss: 0.006037796847522259
# Units: 130, Epochs: 170, Batch Size: 128, Validation Loss: 0.006667828653007746
# Units: 130, Epochs: 200, Batch Size: 8, Validation Loss: 0.005780126433819532
# Units: 130, Epochs: 200, Batch Size: 16, Validation Loss: 0.006184538826346397
# Units: 130, Epochs: 200, Batch Size: 32, Validation Loss: 0.006126916501671076
# Units: 130, Epochs: 200, Batch Size: 64, Validation Loss: 0.00614953925833106
# Units: 130, Epochs: 200, Batch Size: 128, Validation Loss: 0.006496486719697714
# Units: 150, Epochs: 50, Batch Size: 8, Validation Loss: 0.005793829448521137
# Units: 150, Epochs: 50, Batch Size: 16, Validation Loss: 0.006272500846534967
# Units: 150, Epochs: 50, Batch Size: 32, Validation Loss: 0.006467062048614025
# Units: 150, Epochs: 50, Batch Size: 64, Validation Loss: 0.007535193115472794
# Units: 150, Epochs: 50, Batch Size: 128, Validation Loss: 0.013789775781333447
# Units: 150, Epochs: 70, Batch Size: 8, Validation Loss: 0.005815907847136259
# Units: 150, Epochs: 70, Batch Size: 16, Validation Loss: 0.005741361994296312
# Units: 150, Epochs: 70, Batch Size: 32, Validation Loss: 0.006029059179127216
# Units: 150, Epochs: 70, Batch Size: 64, Validation Loss: 0.007069492246955633
# Units: 150, Epochs: 70, Batch Size: 128, Validation Loss: 0.009060848504304886
# Units: 150, Epochs: 90, Batch Size: 8, Validation Loss: 0.005802871659398079
# Units: 150, Epochs: 90, Batch Size: 16, Validation Loss: 0.005979484412819147
# Units: 150, Epochs: 90, Batch Size: 32, Validation Loss: 0.0060396697372198105
# Units: 150, Epochs: 90, Batch Size: 64, Validation Loss: 0.0061646983958780766
# Units: 150, Epochs: 90, Batch Size: 128, Validation Loss: 0.007641265168786049
# Units: 150, Epochs: 110, Batch Size: 8, Validation Loss: 0.0058685303665697575
# Units: 150, Epochs: 110, Batch Size: 16, Validation Loss: 0.005974957253783941
# Units: 150, Epochs: 110, Batch Size: 32, Validation Loss: 0.005940067581832409
# Units: 150, Epochs: 110, Batch Size: 64, Validation Loss: 0.00646880641579628
# Units: 150, Epochs: 110, Batch Size: 128, Validation Loss: 0.006916853599250317
# Units: 150, Epochs: 130, Batch Size: 8, Validation Loss: 0.0059311119839549065
# Units: 150, Epochs: 130, Batch Size: 16, Validation Loss: 0.006118884775787592
# Units: 150, Epochs: 130, Batch Size: 32, Validation Loss: 0.0059004114009439945
# Units: 150, Epochs: 130, Batch Size: 64, Validation Loss: 0.006107601337134838
# Units: 150, Epochs: 130, Batch Size: 128, Validation Loss: 0.006619408261030912
# Units: 150, Epochs: 150, Batch Size: 8, Validation Loss: 0.005839507561177015
# Units: 150, Epochs: 150, Batch Size: 16, Validation Loss: 0.006080044433474541
# Units: 150, Epochs: 150, Batch Size: 32, Validation Loss: 0.005907702259719372
# Units: 150, Epochs: 150, Batch Size: 64, Validation Loss: 0.0059349555522203445
# Units: 150, Epochs: 150, Batch Size: 128, Validation Loss: 0.00655039306730032
# Units: 150, Epochs: 170, Batch Size: 8, Validation Loss: 0.005824566353112459
# Units: 150, Epochs: 170, Batch Size: 16, Validation Loss: 0.005924144759774208
# Units: 150, Epochs: 170, Batch Size: 32, Validation Loss: 0.005830531939864159
# Units: 150, Epochs: 170, Batch Size: 64, Validation Loss: 0.005974886938929558
# Units: 150, Epochs: 170, Batch Size: 128, Validation Loss: 0.0064451261423528194
# Units: 150, Epochs: 200, Batch Size: 8, Validation Loss: 0.005811766255646944
# Units: 150, Epochs: 200, Batch Size: 16, Validation Loss: 0.006019228138029575
# Units: 150, Epochs: 200, Batch Size: 32, Validation Loss: 0.005905972793698311
# Units: 150, Epochs: 200, Batch Size: 64, Validation Loss: 0.005855548195540905
# Units: 150, Epochs: 200, Batch Size: 128, Validation Loss: 0.006334766745567322
# Units: 170, Epochs: 50, Batch Size: 8, Validation Loss: 0.0057549262419342995
# Units: 170, Epochs: 50, Batch Size: 16, Validation Loss: 0.005932878237217665
# Units: 170, Epochs: 50, Batch Size: 32, Validation Loss: 0.006240950897336006
# Units: 170, Epochs: 50, Batch Size: 64, Validation Loss: 0.007436699233949184
# Units: 170, Epochs: 50, Batch Size: 128, Validation Loss: 0.014043699949979782
# Units: 170, Epochs: 70, Batch Size: 8, Validation Loss: 0.006001695524901152
# Units: 170, Epochs: 70, Batch Size: 16, Validation Loss: 0.005980359390377998
# Units: 170, Epochs: 70, Batch Size: 32, Validation Loss: 0.006163029000163078
# Units: 170, Epochs: 70, Batch Size: 64, Validation Loss: 0.006274380721151829
# Units: 170, Epochs: 70, Batch Size: 128, Validation Loss: 0.007070950698107481
# Units: 170, Epochs: 90, Batch Size: 8, Validation Loss: 0.005867310333997011
# Units: 170, Epochs: 90, Batch Size: 16, Validation Loss: 0.005974637810140848
# Units: 170, Epochs: 90, Batch Size: 32, Validation Loss: 0.006217236630618572
# Units: 170, Epochs: 90, Batch Size: 64, Validation Loss: 0.006214844528585672
# Units: 170, Epochs: 90, Batch Size: 128, Validation Loss: 0.006606771145015955
# Units: 170, Epochs: 110, Batch Size: 8, Validation Loss: 0.005841589532792568
# Units: 170, Epochs: 110, Batch Size: 16, Validation Loss: 0.005904344841837883
# Units: 170, Epochs: 110, Batch Size: 32, Validation Loss: 0.006155344191938639
# Units: 170, Epochs: 110, Batch Size: 64, Validation Loss: 0.006292702630162239
# Units: 170, Epochs: 110, Batch Size: 128, Validation Loss: 0.00668207835406065
# Units: 170, Epochs: 130, Batch Size: 8, Validation Loss: 0.005768705625087023
# Units: 170, Epochs: 130, Batch Size: 16, Validation Loss: 0.006029143463820219
# Units: 170, Epochs: 130, Batch Size: 32, Validation Loss: 0.005987186450511217
# Units: 170, Epochs: 130, Batch Size: 64, Validation Loss: 0.006091760005801916
# Units: 170, Epochs: 130, Batch Size: 128, Validation Loss: 0.006275962572544813
# Units: 170, Epochs: 150, Batch Size: 8, Validation Loss: 0.005784059874713421
# Units: 170, Epochs: 150, Batch Size: 16, Validation Loss: 0.005952003411948681
# Units: 170, Epochs: 150, Batch Size: 32, Validation Loss: 0.006004022434353828
# Units: 170, Epochs: 150, Batch Size: 64, Validation Loss: 0.006051951553672552
# Units: 170, Epochs: 150, Batch Size: 128, Validation Loss: 0.00634068064391613
# Units: 170, Epochs: 170, Batch Size: 8, Validation Loss: 0.0058758314698934555
# Units: 170, Epochs: 170, Batch Size: 16, Validation Loss: 0.0060283588245511055
# Units: 170, Epochs: 170, Batch Size: 32, Validation Loss: 0.006081483792513609
# Units: 170, Epochs: 170, Batch Size: 64, Validation Loss: 0.005993174854665995
# Units: 170, Epochs: 170, Batch Size: 128, Validation Loss: 0.006233661901205778
# Units: 170, Epochs: 200, Batch Size: 8, Validation Loss: 0.005759866442531347
# Units: 170, Epochs: 200, Batch Size: 16, Validation Loss: 0.005877976305782795
# Units: 170, Epochs: 200, Batch Size: 32, Validation Loss: 0.005811430048197508
# Units: 170, Epochs: 200, Batch Size: 64, Validation Loss: 0.005800951737910509
# Units: 170, Epochs: 200, Batch Size: 128, Validation Loss: 0.006254780106246471
# Units: 200, Epochs: 50, Batch Size: 8, Validation Loss: 0.0057549988850951195
# Units: 200, Epochs: 50, Batch Size: 16, Validation Loss: 0.006037795916199684
# Units: 200, Epochs: 50, Batch Size: 32, Validation Loss: 0.006087558344006538
# Units: 200, Epochs: 50, Batch Size: 64, Validation Loss: 0.006409278605133295
# Units: 200, Epochs: 50, Batch Size: 128, Validation Loss: 0.009307256899774075
# Units: 200, Epochs: 70, Batch Size: 8, Validation Loss: 0.0058653149753808975
# Units: 200, Epochs: 70, Batch Size: 16, Validation Loss: 0.005926260259002447
# Units: 200, Epochs: 70, Batch Size: 32, Validation Loss: 0.0060286507941782475
# Units: 200, Epochs: 70, Batch Size: 64, Validation Loss: 0.006180454045534134
# Units: 200, Epochs: 70, Batch Size: 128, Validation Loss: 0.006601445842534304
# Units: 200, Epochs: 90, Batch Size: 8, Validation Loss: 0.005928928963840008
# Units: 200, Epochs: 90, Batch Size: 16, Validation Loss: 0.0059846327640116215
# Units: 200, Epochs: 90, Batch Size: 32, Validation Loss: 0.0059362719766795635
# Units: 200, Epochs: 90, Batch Size: 64, Validation Loss: 0.006074019242078066
# Units: 200, Epochs: 90, Batch Size: 128, Validation Loss: 0.007105510216206312
# Units: 200, Epochs: 110, Batch Size: 8, Validation Loss: 0.0057561956346035
# Units: 200, Epochs: 110, Batch Size: 16, Validation Loss: 0.005930633749812841
# Units: 200, Epochs: 110, Batch Size: 32, Validation Loss: 0.006041856482625008
# Units: 200, Epochs: 110, Batch Size: 64, Validation Loss: 0.006316170562058687
# Units: 200, Epochs: 110, Batch Size: 128, Validation Loss: 0.006463474594056606
# Units: 200, Epochs: 130, Batch Size: 8, Validation Loss: 0.0057941460981965065
# Units: 200, Epochs: 130, Batch Size: 16, Validation Loss: 0.0059148576110601425
# Units: 200, Epochs: 130, Batch Size: 32, Validation Loss: 0.005955273285508156
# Units: 200, Epochs: 130, Batch Size: 64, Validation Loss: 0.005913949105888605
# Units: 200, Epochs: 130, Batch Size: 128, Validation Loss: 0.006254637148231268
# Units: 200, Epochs: 150, Batch Size: 8, Validation Loss: 0.005812987219542265
# Units: 200, Epochs: 150, Batch Size: 16, Validation Loss: 0.005846632644534111
# Units: 200, Epochs: 150, Batch Size: 32, Validation Loss: 0.005773305427283049
# Units: 200, Epochs: 150, Batch Size: 64, Validation Loss: 0.005851317662745714
# Units: 200, Epochs: 150, Batch Size: 128, Validation Loss: 0.0060949865728616714
# Units: 200, Epochs: 170, Batch Size: 8, Validation Loss: 0.005877931136637926
# Units: 200, Epochs: 170, Batch Size: 16, Validation Loss: 0.005947106517851353
# Units: 200, Epochs: 170, Batch Size: 32, Validation Loss: 0.005881255958229303
# Units: 200, Epochs: 170, Batch Size: 64, Validation Loss: 0.0057424455881118774
# Units: 200, Epochs: 170, Batch Size: 128, Validation Loss: 0.00622820807620883
# Units: 200, Epochs: 200, Batch Size: 8, Validation Loss: 0.005888393148779869
# Units: 200, Epochs: 200, Batch Size: 16, Validation Loss: 0.005947398953139782
# Units: 200, Epochs: 200, Batch Size: 32, Validation Loss: 0.005934190936386585
# Units: 200, Epochs: 200, Batch Size: 64, Validation Loss: 0.005839747842401266
# Units: 200, Epochs: 200, Batch Size: 128, Validation Loss: 0.0061504654586315155

# %%
import matplotlib.pyplot as plt
import numpy as np

# Misalkan 'history' adalah objek yang didapatkan setelah melatih model
train_loss = history.history['loss']
val_loss = history.history.get('val_loss')  # Jika validasi split digunakan

# Ubah list menjadi array NumPy
train_loss_np = np.array(train_loss)
val_loss_np = np.array(val_loss) if val_loss else None

# Siapkan plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot loss pelatihan
ax.plot(train_loss_np, label='Loss Pelatihan', linestyle='-', color='blue')

# Plot loss validasi (jika tersedia)
if val_loss_np is not None:
    ax.plot(val_loss_np, label='Loss Validasi', linestyle='--', color='orange')

# Label dan judul
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss Pelatihan dan Validasi')

# Legenda
ax.legend()

# Grid (opsional)
ax.grid(True)

# Tampilkan atau simpan plot
plt.show()  # atau plt.savefig('loss_curve.png')

#の説明 ada di komentar di bawah kode

# %%
model.summary()
# Out:
# Model: "sequential_403"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_806 (LSTM)             (None, 1, 200)            162400
#
#  lstm_807 (LSTM)             (None, 200)               320800
#
#  dense_403 (Dense)           (None, 1)                 201
#
# =================================================================
# Total params: 483,401
# Trainable params: 483,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# Simpan model dalam format .h5
#model.save("modelbener.h5")

# Muat kembali model dari file .h5
model = tf.keras.models.load_model("modelbener.h5")

# Gunakan model seperti yang Anda butuhkan

# %%
predictions = model.predict(testX)
predictions = scaler_harga.inverse_transform(predictions)
testY = scaler_harga.inverse_transform(testY)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
trainY = scaler_harga.inverse_transform(trainY)

# %%
df_test = pd.DataFrame({'Actual': np.squeeze(testY), 'Predicted': np.squeeze(predictions)})
df_test.head(30)
# Out:
#      Actual     Predicted
# 0   44250.0  51030.164062
# 1   43200.0  43509.660156
# 2   39000.0  42730.703125
# 3   34900.0  38812.378906
# 4   33900.0  35064.371094
# 5   34100.0  34209.699219
# 6   36400.0  34360.863281
# 7   36850.0  36469.394531
# 8   35400.0  36625.910156
# 9   35650.0  35188.941406
# 10  39250.0  35323.234375
# 11  43300.0  38645.871094
# 12  43550.0  42468.199219
# 13  42200.0  42576.105469
# 14  41450.0  41190.320312
# 15  43150.0  40518.230469
# 16  43100.0  42164.859375
# 17  49650.0  42089.398438
# 18  46600.0  48153.683594
# 19  42550.0  45129.046875
# 20  42250.0  41533.550781
# 21  43850.0  41309.851562
# 22  45250.0  42709.152344
# 23  38400.0  43958.484375
# 24  37000.0  38092.457031
# 25  51200.0  36553.585938
# 26  56550.0  50125.980469
# 27  48200.0  55071.796875
# 28  39000.0  47137.378906
# 29  43800.0  38677.945312

# %%
#df['Tanggal'] = pd.to_datetime(df['Tanggal'])
#df.set_index('Tanggal', inplace=True)
#df.sort_index(inplace=True)
#df.index = pd.to_datetime(df.index)

# %% [markdown]
# # Hasil Akhir

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error
from matplotlib.dates import MonthLocator, DateFormatter
mape = mean_absolute_percentage_error(testY, predictions)*100

plt.figure(figsize=(30, 10))
plt.plot(df.index[-len(testY):], testY, label='Testing', marker='', color='red', linestyle='-', linewidth=5)
plt.plot(df.index[-len(predictions):], predictions, label='Prediction', marker='', color='green', linestyle='-', linewidth=7)
plt.title(f'MAPE: {mape:.3f}%', fontsize=25)
plt.xlabel('Tanggal', fontsize=25)
plt.ylabel('Harga', fontsize=25)
plt.grid(True, linestyle='--', alpha=1)
plt.legend()

locator = MonthLocator(bymonth=[1, 7])
formatter = DateFormatter('%b %Y')
plt.gca().xaxis.set_major_locator(locator)
plt.gca().xaxis.set_major_formatter(formatter)
plt.xticks(rotation=0)
plt.show()
