# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import matplotlib.dates as mdates
sns.set_style('whitegrid')
# %matplotlib inline
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, Dropout,GRU
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from tensorflow.keras import optimizers, Model
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Load Data

# %%
import os
CURR_FOLDER_PATH = os.getcwd()
BASE_PATH = os.path.dirname(os.path.dirname(CURR_FOLDER_PATH))
DATA_PATH = os.path.join(BASE_PATH, 'Lulus/data')

# %%
df = pd.read_excel(DATA_PATH + '/Hargalagpasartradisionallagvariable.xlsx')
# Data yang digunakan yaitu Harga cabai Rawit dan Harga Bawang putih sebagai Barang Subtitusi Sudah dilakukan lag - 1 Minggu

# %%
df
# Out:
#           Tanggal Harga Cabai Merah Harga Cabai Rawit
# 0    01/ 01/ 2018                 -                 -
# 1    08/ 01/ 2018             38300                 -
# 2    15/ 01/ 2018             42800             42600
# 3    22/ 01/ 2018             37850             42700
# 4    29/ 01/ 2018             38950             42600
# ..            ...               ...               ...
# 308  27/ 11/ 2023             80250             76600
# 309  04/ 12/ 2023             94900             79150
# 310  11/ 12/ 2023             99300             79100
# 311  18/ 12/ 2023             85000             75550
# 312  25/ 12/ 2023                 -             66350
#
# [313 rows x 3 columns]

# %% [markdown]
# # Statistical Analytics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tanggal            313 non-null    object
#  1   Harga Cabai Merah  313 non-null    object
#  2   Harga Cabai Rawit  313 non-null    object
# dtypes: object(3)
# memory usage: 7.5+ KB

# %%
df.shape
# Out:
# (313, 3)

# %%
df.replace('-', pd.NA, inplace=True)

# %%
missing_values = df.isnull().sum()
percentage_missing = (missing_values / df.shape[0]) * 100
print("Jumlah Missing Value per Kolom:")
print(missing_values)
print("\nPersentase Missing Value per Kolom:")
percentage_missing
# Out:
# Jumlah Missing Value per Kolom:
# Tanggal              0
# Harga Cabai Merah    9
# Harga Cabai Rawit    9
# dtype: int64
#
# Persentase Missing Value per Kolom:
# Tanggal              0.000000
# Harga Cabai Merah    2.875399
# Harga Cabai Rawit    2.875399
# dtype: float64

# %%
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/ %m/ %Y')
df['Bulan'] = df['Tanggal'].dt.to_period('M')
mean_values = df.groupby('Bulan').mean()


def fill_missing_with_mean(row):
    if pd.isna(row['Harga Cabai Merah']):
        row['Harga Cabai Merah'] = mean_values.loc[row['Bulan'], 'Harga Cabai Merah']
    if pd.isna(row['Harga Cabai Rawit']):
        row['Harga Cabai Rawit'] = mean_values.loc[row['Bulan'], 'Harga Cabai Rawit']
    return row


df = df.apply(fill_missing_with_mean, axis=1)
print(df)
# Out:
#        Tanggal  Harga Cabai Merah  Harga Cabai Rawit    Bulan
# 0   2018-01-01       39475.000000       42633.333333  2018-01
# 1   2018-01-08       38300.000000       42633.333333  2018-01
# 2   2018-01-15       42800.000000       42600.000000  2018-01
# 3   2018-01-22       37850.000000       42700.000000  2018-01
# 4   2018-01-29       38950.000000       42600.000000  2018-01
# ..         ...                ...                ...      ...
# 308 2023-11-27       80250.000000       76600.000000  2023-11
# 309 2023-12-04       94900.000000       79150.000000  2023-12
# 310 2023-12-11       99300.000000       79100.000000  2023-12
# 311 2023-12-18       85000.000000       75550.000000  2023-12
# 312 2023-12-25       93066.666667       66350.000000  2023-12
#
# [313 rows x 4 columns]

# %%
df['Harga Cabai Merah'] = df['Harga Cabai Merah'].astype('float64')
df['Harga Cabai Rawit'] = df['Harga Cabai Rawit'].astype('float64')

# %%
import seaborn as sns

harga_merah_stats = df['Harga Cabai Merah'].describe()
print("\nStatistik Deskriptif Harga Cabai Merah:")
print(harga_merah_stats)


harga_rawit_stats = df['Harga Cabai Rawit'].describe()
print("\nStatistik Deskriptif Harga Cabai Rawit:")
print(harga_rawit_stats)
# Out:
# Statistik Deskriptif Harga Cabai Merah:
# count       313.000000
# mean      43092.092652
# std       15493.651894
# min       21750.000000
# 25%       31650.000000
# 50%       40800.000000
# 75%       49550.000000
# max      109450.000000
# Name: Harga Cabai Merah, dtype: float64
#
# Statistik Deskriptif Harga Cabai Rawit:
# count       313.000000
# mean      44877.715655
# std       17241.023349
# min       22600.000000
# 25%       30950.000000
# 50%       42000.000000
# 75%       54250.000000
# max      100750.000000
# Name: Harga Cabai Rawit, dtype: float64

# %%
# Visualisasi
plt.figure(figsize=(25, 6))
plt.plot(df.index, df['Harga Cabai Merah'])
plt.title('Data Harga Cabai Merah 1 Januari 2018 - 31 Juli 2023')
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Merah')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Harga Cabai Merah'], kde=True)
plt.title('Distribusi Harga')
plt.xlabel('Harga Cabai Merah')
plt.ylabel('Frekuensi')
plt.show()

# %%
corr_with_target = df[['Harga Cabai Merah','Harga Cabai Rawit']].corr()
# Membuat heatmap
plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(corr_with_target, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5,
                      annot_kws={"size": 25})  # Ukuran font diperbesar menjadi 25

# Memperbesar ukuran font label pada sumbu x dan y
heatmap.set_xticklabels(heatmap.get_xticklabels(), fontsize=20)
heatmap.set_yticklabels(heatmap.get_yticklabels(), fontsize=20)

# Menambahkan judul
plt.title('Korelasi antara Harga Cabai Merah dan Barang Subtitusi', fontsize=16)

# Menampilkan heatmap
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
df.head()
sns.lmplot(x="Harga Cabai Merah", y="Harga Cabai Rawit", data=df)
plt.show()

# %%
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
sns.pairplot(df, diag_kind=None)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# Ubah kolom 'Tanggal' menjadi tipe datetime dan tetapkan sebagai indeks
df['Tanggal'] = pd.to_datetime(df['Tanggal'], format='%d/%m/%Y')
df.set_index('Tanggal', inplace=True)

# Melakukan dekomposisi musiman
decomposition = seasonal_decompose(df['Harga Cabai Merah'], model='additive')

# Menampilkan hasil
plt.figure(figsize=(15, 8))

# Data asli
plt.subplot(411)
plt.plot(df.index, df['Harga Cabai Merah'], label='Original')
plt.legend(loc='upper left')

# Trend
plt.subplot(412)
plt.plot(decomposition.trend.index, decomposition.trend, label='Trend')
plt.legend(loc='upper left')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing Data

# %%
scaler_rr = MinMaxScaler(feature_range=(0, 1))
scaler_harga = MinMaxScaler(feature_range=(0, 1))
df['Harga Cabai Merah_Scaled'] = scaler_harga.fit_transform(df[['Harga Cabai Merah']])
df['Harga Cabai Rawit_Scaled'] = scaler_rr.fit_transform(df[['Harga Cabai Rawit']])

# %%
df.head()
# Out:
#             Harga Cabai Merah  Harga Cabai Rawit    Bulan  \
# Tanggal
# 2018-01-01            39475.0       42633.333333  2018-01
# 2018-01-08            38300.0       42633.333333  2018-01
# 2018-01-15            42800.0       42600.000000  2018-01
# 2018-01-22            37850.0       42700.000000  2018-01
# 2018-01-29            38950.0       42600.000000  2018-01
#
#             Harga Cabai Merah_Scaled  Harga Cabai Rawit_Scaled
# Tanggal
# 2018-01-01                  0.202109                  0.256345
# 2018-01-08                  0.188712                  0.256345
# 2018-01-15                  0.240023                  0.255918
# 2018-01-22                  0.183580                  0.257198
# 2018-01-29                  0.196123                  0.255918

# %% [markdown]
# # Split Data

# %%
from sklearn.model_selection import train_test_split

selected_columns = ['Harga Cabai Merah_Scaled', 'Harga Cabai Rawit_Scaled']
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)][selected_columns].values
        dataX.append(a)
        dataY.append(dataset[i + look_back:i + look_back + 1]['Harga Cabai Merah_Scaled'].values)
    return np.array(dataX), np.array(dataY)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# Memisahkan 20% data latih sebagai data validasi tanpa mengacak urutan waktu
trainX, valX, trainY, valY = train_test_split(trainX, trainY, test_size=0.2, shuffle=False)

print("Ukuran data latih setelah pembagian:", trainX.shape)
print("Ukuran data validasi setelah pembagian:", valX.shape)
print("Ukuran data uji:", testX.shape)
# Out:
# Ukuran data latih setelah pembagian: (199, 1, 2)
# Ukuran data validasi setelah pembagian: (50, 1, 2)
# Ukuran data uji: (62, 1, 2)

# %% [markdown]
# # Pembuatan Model

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

model = Sequential()
model.add(LSTM(units=30, return_sequences=True, input_shape=(look_back, 2), activation='relu'))
model.add(LSTM(units=30, activation='relu'))
model.add(Dense(units=1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error')
history = model.fit(trainX, trainY, epochs=130, batch_size=8, verbose=2)
# Out:
# Epoch 1/130
# 25/25 - 2s - loss: 0.0457 - 2s/epoch - 95ms/step
# Epoch 2/130
# 25/25 - 0s - loss: 0.0275 - 61ms/epoch - 2ms/step
# Epoch 3/130
# 25/25 - 0s - loss: 0.0172 - 60ms/epoch - 2ms/step
# Epoch 4/130
# 25/25 - 0s - loss: 0.0150 - 60ms/epoch - 2ms/step
# Epoch 5/130
# 25/25 - 0s - loss: 0.0136 - 57ms/epoch - 2ms/step
# Epoch 6/130
# 25/25 - 0s - loss: 0.0122 - 51ms/epoch - 2ms/step
# Epoch 7/130
# 25/25 - 0s - loss: 0.0109 - 55ms/epoch - 2ms/step
# Epoch 8/130
# 25/25 - 0s - loss: 0.0099 - 121ms/epoch - 5ms/step
# Epoch 9/130
# 25/25 - 0s - loss: 0.0087 - 66ms/epoch - 3ms/step
# Epoch 10/130
# 25/25 - 0s - loss: 0.0079 - 65ms/epoch - 3ms/step
# Epoch 11/130
# 25/25 - 0s - loss: 0.0074 - 56ms/epoch - 2ms/step
# Epoch 12/130
# 25/25 - 0s - loss: 0.0069 - 62ms/epoch - 2ms/step
# Epoch 13/130
# 25/25 - 0s - loss: 0.0066 - 51ms/epoch - 2ms/step
# Epoch 14/130
# 25/25 - 0s - loss: 0.0063 - 49ms/epoch - 2ms/step
# Epoch 15/130
# 25/25 - 0s - loss: 0.0060 - 45ms/epoch - 2ms/step
# Epoch 16/130
# 25/25 - 0s - loss: 0.0058 - 60ms/epoch - 2ms/step
# Epoch 17/130
# 25/25 - 0s - loss: 0.0056 - 56ms/epoch - 2ms/step
# Epoch 18/130
# 25/25 - 0s - loss: 0.0054 - 52ms/epoch - 2ms/step
# Epoch 19/130
# 25/25 - 0s - loss: 0.0051 - 45ms/epoch - 2ms/step
# Epoch 20/130
# 25/25 - 0s - loss: 0.0050 - 65ms/epoch - 3ms/step
# Epoch 21/130
# 25/25 - 0s - loss: 0.0050 - 60ms/epoch - 2ms/step
# Epoch 22/130
# 25/25 - 0s - loss: 0.0048 - 56ms/epoch - 2ms/step
# Epoch 23/130
# 25/25 - 0s - loss: 0.0048 - 60ms/epoch - 2ms/step
# Epoch 24/130
# 25/25 - 0s - loss: 0.0047 - 45ms/epoch - 2ms/step
# Epoch 25/130
# 25/25 - 0s - loss: 0.0046 - 42ms/epoch - 2ms/step
# Epoch 26/130
# 25/25 - 0s - loss: 0.0045 - 43ms/epoch - 2ms/step
# Epoch 27/130
# 25/25 - 0s - loss: 0.0045 - 49ms/epoch - 2ms/step
# Epoch 28/130
# 25/25 - 0s - loss: 0.0045 - 133ms/epoch - 5ms/step
# Epoch 29/130
# 25/25 - 0s - loss: 0.0045 - 66ms/epoch - 3ms/step
# Epoch 30/130
# 25/25 - 0s - loss: 0.0044 - 50ms/epoch - 2ms/step
# Epoch 31/130
# 25/25 - 0s - loss: 0.0044 - 55ms/epoch - 2ms/step
# Epoch 32/130
# 25/25 - 0s - loss: 0.0044 - 53ms/epoch - 2ms/step
# Epoch 33/130
# 25/25 - 0s - loss: 0.0044 - 45ms/epoch - 2ms/step
# Epoch 34/130
# 25/25 - 0s - loss: 0.0044 - 46ms/epoch - 2ms/step
# Epoch 35/130
# 25/25 - 0s - loss: 0.0044 - 66ms/epoch - 3ms/step
# Epoch 36/130
# 25/25 - 0s - loss: 0.0043 - 65ms/epoch - 3ms/step
# Epoch 37/130
# 25/25 - 0s - loss: 0.0045 - 47ms/epoch - 2ms/step
# Epoch 38/130
# 25/25 - 0s - loss: 0.0043 - 44ms/epoch - 2ms/step
# Epoch 39/130
# 25/25 - 0s - loss: 0.0043 - 44ms/epoch - 2ms/step
# Epoch 40/130
# 25/25 - 0s - loss: 0.0043 - 48ms/epoch - 2ms/step
# Epoch 41/130
# 25/25 - 0s - loss: 0.0044 - 68ms/epoch - 3ms/step
# Epoch 42/130
# 25/25 - 0s - loss: 0.0044 - 65ms/epoch - 3ms/step
# Epoch 43/130
# 25/25 - 0s - loss: 0.0043 - 61ms/epoch - 2ms/step
# Epoch 44/130
# 25/25 - 0s - loss: 0.0042 - 53ms/epoch - 2ms/step
# Epoch 45/130
# 25/25 - 0s - loss: 0.0042 - 43ms/epoch - 2ms/step
# Epoch 46/130
# 25/25 - 0s - loss: 0.0042 - 43ms/epoch - 2ms/step
# Epoch 47/130
# 25/25 - 0s - loss: 0.0042 - 43ms/epoch - 2ms/step
# Epoch 48/130
# 25/25 - 0s - loss: 0.0043 - 45ms/epoch - 2ms/step
# Epoch 49/130
# 25/25 - 0s - loss: 0.0043 - 44ms/epoch - 2ms/step
# Epoch 50/130
# 25/25 - 0s - loss: 0.0043 - 54ms/epoch - 2ms/step
# Epoch 51/130
# 25/25 - 0s - loss: 0.0043 - 60ms/epoch - 2ms/step
# Epoch 52/130
# 25/25 - 0s - loss: 0.0042 - 64ms/epoch - 3ms/step
# Epoch 53/130
# 25/25 - 0s - loss: 0.0042 - 65ms/epoch - 3ms/step
# Epoch 54/130
# 25/25 - 0s - loss: 0.0042 - 60ms/epoch - 2ms/step
# Epoch 55/130
# 25/25 - 0s - loss: 0.0042 - 60ms/epoch - 2ms/step
# Epoch 56/130
# 25/25 - 0s - loss: 0.0042 - 59ms/epoch - 2ms/step
# Epoch 57/130
# 25/25 - 0s - loss: 0.0042 - 104ms/epoch - 4ms/step
# Epoch 58/130
# 25/25 - 0s - loss: 0.0041 - 94ms/epoch - 4ms/step
# Epoch 59/130
# 25/25 - 0s - loss: 0.0042 - 63ms/epoch - 3ms/step
# Epoch 60/130
# 25/25 - 0s - loss: 0.0043 - 61ms/epoch - 2ms/step
# Epoch 61/130
# 25/25 - 0s - loss: 0.0043 - 57ms/epoch - 2ms/step
# Epoch 62/130
# 25/25 - 0s - loss: 0.0041 - 63ms/epoch - 3ms/step
# Epoch 63/130
# 25/25 - 0s - loss: 0.0042 - 56ms/epoch - 2ms/step
# Epoch 64/130
# 25/25 - 0s - loss: 0.0040 - 51ms/epoch - 2ms/step
# Epoch 65/130
# 25/25 - 0s - loss: 0.0042 - 49ms/epoch - 2ms/step
# Epoch 66/130
# 25/25 - 0s - loss: 0.0041 - 52ms/epoch - 2ms/step
# Epoch 67/130
# 25/25 - 0s - loss: 0.0042 - 49ms/epoch - 2ms/step
# Epoch 68/130
# 25/25 - 0s - loss: 0.0041 - 50ms/epoch - 2ms/step
# Epoch 69/130
# 25/25 - 0s - loss: 0.0041 - 49ms/epoch - 2ms/step
# Epoch 70/130
# 25/25 - 0s - loss: 0.0041 - 57ms/epoch - 2ms/step
# Epoch 71/130
# 25/25 - 0s - loss: 0.0041 - 65ms/epoch - 3ms/step
# Epoch 72/130
# 25/25 - 0s - loss: 0.0040 - 54ms/epoch - 2ms/step
# Epoch 73/130
# 25/25 - 0s - loss: 0.0040 - 56ms/epoch - 2ms/step
# Epoch 74/130
# 25/25 - 0s - loss: 0.0040 - 55ms/epoch - 2ms/step
# Epoch 75/130
# 25/25 - 0s - loss: 0.0040 - 48ms/epoch - 2ms/step
# Epoch 76/130
# 25/25 - 0s - loss: 0.0042 - 56ms/epoch - 2ms/step
# Epoch 77/130
# 25/25 - 0s - loss: 0.0040 - 48ms/epoch - 2ms/step
# Epoch 78/130
# 25/25 - 0s - loss: 0.0040 - 46ms/epoch - 2ms/step
# Epoch 79/130
# 25/25 - 0s - loss: 0.0040 - 44ms/epoch - 2ms/step
# Epoch 80/130
# 25/25 - 0s - loss: 0.0040 - 43ms/epoch - 2ms/step
# Epoch 81/130
# 25/25 - 0s - loss: 0.0039 - 43ms/epoch - 2ms/step
# Epoch 82/130
# 25/25 - 0s - loss: 0.0041 - 46ms/epoch - 2ms/step
# Epoch 83/130
# 25/25 - 0s - loss: 0.0041 - 43ms/epoch - 2ms/step
# Epoch 84/130
# 25/25 - 0s - loss: 0.0041 - 41ms/epoch - 2ms/step
# Epoch 85/130
# 25/25 - 0s - loss: 0.0040 - 44ms/epoch - 2ms/step
# Epoch 86/130
# 25/25 - 0s - loss: 0.0041 - 45ms/epoch - 2ms/step
# Epoch 87/130
# 25/25 - 0s - loss: 0.0040 - 44ms/epoch - 2ms/step
# Epoch 88/130
# 25/25 - 0s - loss: 0.0039 - 44ms/epoch - 2ms/step
# Epoch 89/130
# 25/25 - 0s - loss: 0.0041 - 44ms/epoch - 2ms/step
# Epoch 90/130
# 25/25 - 0s - loss: 0.0039 - 42ms/epoch - 2ms/step
# Epoch 91/130
# 25/25 - 0s - loss: 0.0039 - 43ms/epoch - 2ms/step
# Epoch 92/130
# 25/25 - 0s - loss: 0.0039 - 49ms/epoch - 2ms/step
# Epoch 93/130
# 25/25 - 0s - loss: 0.0039 - 46ms/epoch - 2ms/step
# Epoch 94/130
# 25/25 - 0s - loss: 0.0039 - 45ms/epoch - 2ms/step
# Epoch 95/130
# 25/25 - 0s - loss: 0.0040 - 46ms/epoch - 2ms/step
# Epoch 96/130
# 25/25 - 0s - loss: 0.0039 - 44ms/epoch - 2ms/step
# Epoch 97/130
# 25/25 - 0s - loss: 0.0040 - 44ms/epoch - 2ms/step
# Epoch 98/130
# 25/25 - 0s - loss: 0.0040 - 44ms/epoch - 2ms/step
# Epoch 99/130
# 25/25 - 0s - loss: 0.0038 - 43ms/epoch - 2ms/step
# Epoch 100/130
# 25/25 - 0s - loss: 0.0038 - 44ms/epoch - 2ms/step
# Epoch 101/130
# 25/25 - 0s - loss: 0.0040 - 51ms/epoch - 2ms/step
# Epoch 102/130
# 25/25 - 0s - loss: 0.0039 - 43ms/epoch - 2ms/step
# Epoch 103/130
# 25/25 - 0s - loss: 0.0039 - 44ms/epoch - 2ms/step
# Epoch 104/130
# 25/25 - 0s - loss: 0.0038 - 45ms/epoch - 2ms/step
# Epoch 105/130
# 25/25 - 0s - loss: 0.0038 - 46ms/epoch - 2ms/step
# Epoch 106/130
# 25/25 - 0s - loss: 0.0041 - 45ms/epoch - 2ms/step
# Epoch 107/130
# 25/25 - 0s - loss: 0.0039 - 43ms/epoch - 2ms/step
# Epoch 108/130
# 25/25 - 0s - loss: 0.0038 - 43ms/epoch - 2ms/step
# Epoch 109/130
# 25/25 - 0s - loss: 0.0039 - 97ms/epoch - 4ms/step
# Epoch 110/130
# 25/25 - 0s - loss: 0.0038 - 59ms/epoch - 2ms/step
# Epoch 111/130
# 25/25 - 0s - loss: 0.0038 - 49ms/epoch - 2ms/step
# Epoch 112/130
# 25/25 - 0s - loss: 0.0037 - 57ms/epoch - 2ms/step
# Epoch 113/130
# 25/25 - 0s - loss: 0.0039 - 66ms/epoch - 3ms/step
# Epoch 114/130
# 25/25 - 0s - loss: 0.0037 - 55ms/epoch - 2ms/step
# Epoch 115/130
# 25/25 - 0s - loss: 0.0038 - 57ms/epoch - 2ms/step
# Epoch 116/130
# 25/25 - 0s - loss: 0.0037 - 65ms/epoch - 3ms/step
# Epoch 117/130
# 25/25 - 0s - loss: 0.0037 - 50ms/epoch - 2ms/step
# Epoch 118/130
# 25/25 - 0s - loss: 0.0037 - 66ms/epoch - 3ms/step
# Epoch 119/130
# 25/25 - 0s - loss: 0.0037 - 61ms/epoch - 2ms/step
# Epoch 120/130
# 25/25 - 0s - loss: 0.0038 - 43ms/epoch - 2ms/step
# Epoch 121/130
# 25/25 - 0s - loss: 0.0038 - 43ms/epoch - 2ms/step
# Epoch 122/130
# 25/25 - 0s - loss: 0.0037 - 43ms/epoch - 2ms/step
# Epoch 123/130
# 25/25 - 0s - loss: 0.0038 - 42ms/epoch - 2ms/step
# Epoch 124/130
# 25/25 - 0s - loss: 0.0037 - 42ms/epoch - 2ms/step
# Epoch 125/130
# 25/25 - 0s - loss: 0.0037 - 44ms/epoch - 2ms/step
# Epoch 126/130
# 25/25 - 0s - loss: 0.0037 - 44ms/epoch - 2ms/step
# Epoch 127/130
# 25/25 - 0s - loss: 0.0037 - 44ms/epoch - 2ms/step
# Epoch 128/130
# 25/25 - 0s - loss: 0.0038 - 45ms/epoch - 2ms/step
# Epoch 129/130
# 25/25 - 0s - loss: 0.0039 - 50ms/epoch - 2ms/step
# Epoch 130/130
# 25/25 - 0s - loss: 0.0038 - 52ms/epoch - 2ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Misalkan 'history' adalah objek yang didapatkan setelah melatih model
train_loss = history.history['loss']
val_loss = history.history.get('val_loss')  # Jika validasi split digunakan

# Ubah list menjadi array NumPy
train_loss_np = np.array(train_loss)
val_loss_np = np.array(val_loss) if val_loss else None

# Siapkan plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot loss pelatihan
ax.plot(train_loss_np, label='Loss Pelatihan', linestyle='-', color='blue')

# Plot loss validasi (jika tersedia)
if val_loss_np is not None:
    ax.plot(val_loss_np, label='Loss Validasi', linestyle='--', color='orange')

# Label dan judul
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss Pelatihan dan Validasi')

# Legenda
ax.legend()

# Grid (opsional)
ax.grid(True)

# Tampilkan atau simpan plot
plt.show()  # atau plt.savefig('loss_curve.png')

#の説明 ada di komentar di bawah kode

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 1, 30)             3960
#
#  lstm_3 (LSTM)               (None, 30)                7320
#
#  dense_1 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 11,311
# Trainable params: 11,311
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf

# Simpan model dalam format .h5
#model.save("MODELROBUSTLAG1.h5")

# Muat kembali model dari file .h5
model = tf.keras.models.load_model("MODELROBUSTLAG1.h5")

# Gunakan model seperti yang Anda butuhkan

# %%
predictions = model.predict(testX)
predictions = scaler_harga.inverse_transform(predictions)
testY = scaler_harga.inverse_transform(testY)
# Out:
# 2/2 [==============================] - 0s 4ms/step

# %%
trainY = scaler_harga.inverse_transform(trainY)

# %%
df_test = pd.DataFrame({'Actual': np.squeeze(testY), 'Predicted': np.squeeze(predictions)})
df_test.head(30)
# Out:
#      Actual     Predicted
# 0   44250.0  51416.843750
# 1   43200.0  43974.636719
# 2   39000.0  43026.742188
# 3   34900.0  39310.941406
# 4   33900.0  35733.425781
# 5   34100.0  34865.089844
# 6   36400.0  35039.792969
# 7   36850.0  37034.027344
# 8   35400.0  37441.261719
# 9   35650.0  36196.761719
# 10  39250.0  36408.789062
# 11  43300.0  39552.023438
# 12  43550.0  43159.000000
# 13  42200.0  43378.464844
# 14  41450.0  42168.878906
# 15  43150.0  41500.261719
# 16  43100.0  43007.171875
# 17  49650.0  42963.855469
# 18  46600.0  48864.230469
# 19  42550.0  46107.917969
# 20  42250.0  42481.539062
# 21  43850.0  42216.671875
# 22  45250.0  43641.367188
# 23  38400.0  44895.312500
# 24  37000.0  38826.367188
# 25  51200.0  37583.488281
# 26  56550.0  50257.375000
# 27  48200.0  55207.910156
# 28  39000.0  47532.871094
# 29  43800.0  39318.546875

# %%
#df['Tanggal'] = pd.to_datetime(df['Tanggal'])
#df.set_index('Tanggal', inplace=True)
#df.sort_index(inplace=True)
#df.index = pd.to_datetime(df.index)

# %% [markdown]
# # Hasil Akhir

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error
from matplotlib.dates import MonthLocator, DateFormatter
mape = mean_absolute_percentage_error(testY, predictions)*100

plt.figure(figsize=(30, 10))
plt.plot(df.index[-len(testY):], testY, label='Testing', marker='', color='red', linestyle='-', linewidth=5)
plt.plot(df.index[-len(predictions):], predictions, label='Prediction', marker='', color='green', linestyle='-', linewidth=7)
plt.title(f'MAPE: {mape:.3f}%', fontsize=25)
plt.xlabel('Tanggal', fontsize=25)
plt.ylabel('Harga', fontsize=25)
plt.grid(True, linestyle='--', alpha=1)
plt.legend()

locator = MonthLocator(bymonth=[1, 7])
formatter = DateFormatter('%b %Y')
plt.gca().xaxis.set_major_locator(locator)
plt.gca().xaxis.set_major_formatter(formatter)
plt.xticks(rotation=0)
plt.show()
