# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.dates as mdates
sns.set_style('whitegrid')
# %matplotlib inline
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Activation, Dropout,GRU
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle
from tensorflow.keras import optimizers, Model
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data

# %%
df=pd.read_excel("datalag.xlsx")
# Data yang digunakan yaitu Harga cabai Rawit dan Harga Bawang putih sebagai Barang Subtitusi Sudah dilakukan lag - 1 Minggu

# %%
df
# Out:
#        Tanggal  Harga Cabai Merah  Harga Bawang Putih  Harga Cabai Rawit
# 0   2018-01-08            34450.0             17300.0            28550.0
# 1   2018-01-15            36050.0             18050.0            33650.0
# 2   2018-01-22            32650.0             18550.0            33800.0
# 3   2018-01-29            30450.0             18050.0            35950.0
# 4   2018-02-05            33100.0             18450.0            36850.0
# ..         ...                ...                 ...                ...
# 286 2023-07-03            46500.0             33350.0            32050.0
# 287 2023-07-10            42050.0             33500.0            34450.0
# 288 2023-07-17            37850.0             35300.0            33450.0
# 289 2023-07-24            34000.0             34650.0            30550.0
# 290 2023-07-31            32550.0             36300.0            29300.0
#
# [291 rows x 4 columns]

# %% [markdown]
# # Statistical Analytics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291 entries, 0 to 290
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Tanggal             291 non-null    datetime64[ns]
#  1   Harga Cabai Merah   290 non-null    float64
#  2   Harga Bawang Putih  290 non-null    float64
#  3   Harga Cabai Rawit   290 non-null    float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 9.2 KB

# %%
df.shape
# Out:
# (291, 4)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
harga_stats = df['Harga Cabai Merah'].describe()
print("\nStatistik Deskriptif Harga:")
print(harga_stats)
plt.figure(figsize=(15, 6))
plt.plot(df['Tanggal'], df['Harga Cabai Merah'])
plt.title('Data Harga Cabai Merah 1 Januari 2018 - 31 Juli 2023')
plt.xlabel('Tanggal')
plt.ylabel('Harga Cabai Merah')
plt.show()
# Out:
# Statistik Deskriptif Harga:
# count      290.000000
# mean     34295.517241
# std      13216.572271
# min      16150.000000
# 25%      24875.000000
# 50%      30975.000000
# 75%      38837.500000
# max      98450.000000
# Name: Harga Cabai Merah, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Harga Cabai Merah'], kde=True)
plt.title('Distribusi Harga')
plt.xlabel('Harga Cabai Merah')
plt.ylabel('Frekuensi')
plt.show()

# %%
corr_with_target = df[['Harga Cabai Merah','Harga Bawang Putih','Harga Cabai Rawit']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_with_target, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Korelasi antara Harga Cabai Merah dan Barang Subtitusi')
plt.show()

# %%
df.describe()
# Out:
#        Harga Cabai Merah  Harga Bawang Putih  Harga Cabai Rawit
# count         290.000000          290.000000         290.000000
# mean        34295.517241        24686.379310       35611.379310
# std         13216.572271         5891.786171       15873.674911
# min         16150.000000        15800.000000       16700.000000
# 25%         24875.000000        21712.500000       22975.000000
# 50%         30975.000000        23450.000000       32000.000000
# 75%         38837.500000        26150.000000       42412.500000
# max         98450.000000        52950.000000       89150.000000

# %% [markdown]
# # Preprocessing Data

# %%
df['Harga Cabai Merah'] = df['Harga Cabai Merah'].astype('float64')
df['Harga Bawang Putih'] = df['Harga Bawang Putih'].astype('float64')
df['Harga Cabai Rawit'] = df['Harga Cabai Rawit'].astype('float64')

# %%
df.isnull().sum()
# Out:
# Tanggal               0
# Harga Cabai Merah     1
# Harga Bawang Putih    1
# Harga Cabai Rawit     1
# dtype: int64

# %%
df = df.fillna(df.mean())
# Out:
# C:\Users\ihsan\AppData\Local\Temp\ipykernel_13536\114435927.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df = df.fillna(df.mean())

# %%
scaler_rr = MinMaxScaler(feature_range=(0, 1))
scaler_harga = MinMaxScaler(feature_range=(0, 1))
df['Harga Cabai Merah_Scaled'] = scaler_harga.fit_transform(df[['Harga Cabai Merah']])
df['Harga Bawang Putih_Scaled'] = scaler_rr.fit_transform(df[['Harga Bawang Putih']])
df['Harga Cabai Rawit_Scaled'] = scaler_rr.fit_transform(df[['Harga Cabai Rawit']])

# %%
df
# Out:
#        Tanggal  Harga Cabai Merah  Harga Bawang Putih  Harga Cabai Rawit  \
# 0   2018-01-08            34450.0             17300.0            28550.0
# 1   2018-01-15            36050.0             18050.0            33650.0
# 2   2018-01-22            32650.0             18550.0            33800.0
# 3   2018-01-29            30450.0             18050.0            35950.0
# 4   2018-02-05            33100.0             18450.0            36850.0
# ..         ...                ...                 ...                ...
# 286 2023-07-03            46500.0             33350.0            32050.0
# 287 2023-07-10            42050.0             33500.0            34450.0
# 288 2023-07-17            37850.0             35300.0            33450.0
# 289 2023-07-24            34000.0             34650.0            30550.0
# 290 2023-07-31            32550.0             36300.0            29300.0
#
#      Harga Cabai Merah_Scaled  Harga Bawang Putih_Scaled  \
# 0                    0.222357                   0.040377
# 1                    0.241798                   0.060565
# 2                    0.200486                   0.074024
# 3                    0.173755                   0.060565
# 4                    0.205954                   0.071332
# ..                        ...                        ...
# 286                  0.368773                   0.472409
# 287                  0.314702                   0.476447
# 288                  0.263670                   0.524899
# 289                  0.216889                   0.507402
# 290                  0.199271                   0.551817
#
#      Harga Cabai Rawit_Scaled
# 0                    0.163561
# 1                    0.233954
# 2                    0.236025
# 3                    0.265700
# 4                    0.278123
# ..                        ...
# 286                  0.211870
# 287                  0.244997
# 288                  0.231194
# 289                  0.191166
# 290                  0.173913
#
# [291 rows x 7 columns]

# %% [markdown]
# # Split Data

# %%
selected_columns = ['Harga Cabai Merah_Scaled']
train_size = int(len(df) * 0.8)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back)][selected_columns].values
        dataX.append(a)
        dataY.append(dataset[i + look_back:i + look_back + 1]['Harga Cabai Merah_Scaled'].values)
    return np.array(dataX), np.array(dataY)

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], len(selected_columns)))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], len(selected_columns)))

# %% [markdown]
# # Pembuatan Model

# %% [markdown]
# from tensorflow.keras.optimizers import Nadam
# from tensorflow.keras.layers import LSTM, Dense, Dropout
# from tensorflow.keras.models import Sequential
#
# new_learning_rate = 0.001
# custom_optimizer = Nadam(learning_rate=new_learning_rate)
#
# model = Sequential()
# model.add(LSTM(50, return_sequences=True, input_shape=(look_back, 3), activation='tanh', recurrent_activation='sigmoid', bias_initializer='zeros'))
# model.add(LSTM(50, return_sequences=False, activation='tanh', recurrent_activation='sigmoid', bias_initializer='zeros'))
# model.add(Dense(1))
#
# model.compile(optimizer=custom_optimizer, loss='mean_squared_error')
# model.fit(trainX, trainY, epochs=150, batch_size=64, verbose=2)

# %%
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(look_back, 1), activation='relu'))
model.add(LSTM(units=64, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=1, activation='linear'))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(trainX, trainY, epochs=60, batch_size=64, verbose=2)
# Out:
# Epoch 1/60
# 4/4 - 1s - loss: 0.0575 - 1s/epoch - 367ms/step
# Epoch 2/60
# 4/4 - 0s - loss: 0.0542 - 8ms/epoch - 2ms/step
# Epoch 3/60
# 4/4 - 0s - loss: 0.0512 - 10ms/epoch - 3ms/step
# Epoch 4/60
# 4/4 - 0s - loss: 0.0481 - 8ms/epoch - 2ms/step
# Epoch 5/60
# 4/4 - 0s - loss: 0.0451 - 9ms/epoch - 2ms/step
# Epoch 6/60
# 4/4 - 0s - loss: 0.0420 - 10ms/epoch - 3ms/step
# Epoch 7/60
# 4/4 - 0s - loss: 0.0391 - 10ms/epoch - 3ms/step
# Epoch 8/60
# 4/4 - 0s - loss: 0.0361 - 10ms/epoch - 2ms/step
# Epoch 9/60
# 4/4 - 0s - loss: 0.0332 - 11ms/epoch - 3ms/step
# Epoch 10/60
# 4/4 - 0s - loss: 0.0305 - 10ms/epoch - 3ms/step
# Epoch 11/60
# 4/4 - 0s - loss: 0.0277 - 11ms/epoch - 3ms/step
# Epoch 12/60
# 4/4 - 0s - loss: 0.0252 - 9ms/epoch - 2ms/step
# Epoch 13/60
# 4/4 - 0s - loss: 0.0230 - 8ms/epoch - 2ms/step
# Epoch 14/60
# 4/4 - 0s - loss: 0.0207 - 9ms/epoch - 2ms/step
# Epoch 15/60
# 4/4 - 0s - loss: 0.0189 - 8ms/epoch - 2ms/step
# Epoch 16/60
# 4/4 - 0s - loss: 0.0177 - 8ms/epoch - 2ms/step
# Epoch 17/60
# 4/4 - 0s - loss: 0.0166 - 10ms/epoch - 3ms/step
# Epoch 18/60
# 4/4 - 0s - loss: 0.0159 - 8ms/epoch - 2ms/step
# Epoch 19/60
# 4/4 - 0s - loss: 0.0157 - 9ms/epoch - 2ms/step
# Epoch 20/60
# 4/4 - 0s - loss: 0.0155 - 10ms/epoch - 2ms/step
# Epoch 21/60
# 4/4 - 0s - loss: 0.0149 - 9ms/epoch - 2ms/step
# Epoch 22/60
# 4/4 - 0s - loss: 0.0150 - 8ms/epoch - 2ms/step
# Epoch 23/60
# 4/4 - 0s - loss: 0.0154 - 9ms/epoch - 2ms/step
# Epoch 24/60
# 4/4 - 0s - loss: 0.0142 - 9ms/epoch - 2ms/step
# Epoch 25/60
# 4/4 - 0s - loss: 0.0137 - 8ms/epoch - 2ms/step
# Epoch 26/60
# 4/4 - 0s - loss: 0.0143 - 9ms/epoch - 2ms/step
# Epoch 27/60
# 4/4 - 0s - loss: 0.0143 - 9ms/epoch - 2ms/step
# Epoch 28/60
# 4/4 - 0s - loss: 0.0139 - 8ms/epoch - 2ms/step
# Epoch 29/60
# 4/4 - 0s - loss: 0.0136 - 9ms/epoch - 2ms/step
# Epoch 30/60
# 4/4 - 0s - loss: 0.0133 - 8ms/epoch - 2ms/step
# Epoch 31/60
# 4/4 - 0s - loss: 0.0125 - 10ms/epoch - 2ms/step
# Epoch 32/60
# 4/4 - 0s - loss: 0.0124 - 8ms/epoch - 2ms/step
# Epoch 33/60
# 4/4 - 0s - loss: 0.0120 - 9ms/epoch - 2ms/step
# Epoch 34/60
# 4/4 - 0s - loss: 0.0121 - 7ms/epoch - 2ms/step
# Epoch 35/60
# 4/4 - 0s - loss: 0.0116 - 8ms/epoch - 2ms/step
# Epoch 36/60
# 4/4 - 0s - loss: 0.0113 - 8ms/epoch - 2ms/step
# Epoch 37/60
# 4/4 - 0s - loss: 0.0108 - 8ms/epoch - 2ms/step
# Epoch 38/60
# 4/4 - 0s - loss: 0.0103 - 9ms/epoch - 2ms/step
# Epoch 39/60
# 4/4 - 0s - loss: 0.0100 - 8ms/epoch - 2ms/step
# Epoch 40/60
# 4/4 - 0s - loss: 0.0099 - 9ms/epoch - 2ms/step
# Epoch 41/60
# 4/4 - 0s - loss: 0.0094 - 9ms/epoch - 2ms/step
# Epoch 42/60
# 4/4 - 0s - loss: 0.0092 - 9ms/epoch - 2ms/step
# Epoch 43/60
# 4/4 - 0s - loss: 0.0089 - 8ms/epoch - 2ms/step
# Epoch 44/60
# 4/4 - 0s - loss: 0.0083 - 8ms/epoch - 2ms/step
# Epoch 45/60
# 4/4 - 0s - loss: 0.0079 - 8ms/epoch - 2ms/step
# Epoch 46/60
# 4/4 - 0s - loss: 0.0077 - 9ms/epoch - 2ms/step
# Epoch 47/60
# 4/4 - 0s - loss: 0.0072 - 8ms/epoch - 2ms/step
# Epoch 48/60
# 4/4 - 0s - loss: 0.0073 - 16ms/epoch - 4ms/step
# Epoch 49/60
# 4/4 - 0s - loss: 0.0071 - 9ms/epoch - 2ms/step
# Epoch 50/60
# 4/4 - 0s - loss: 0.0066 - 9ms/epoch - 2ms/step
# Epoch 51/60
# 4/4 - 0s - loss: 0.0068 - 9ms/epoch - 2ms/step
# Epoch 52/60
# 4/4 - 0s - loss: 0.0058 - 8ms/epoch - 2ms/step
# Epoch 53/60
# 4/4 - 0s - loss: 0.0053 - 8ms/epoch - 2ms/step
# Epoch 54/60
# 4/4 - 0s - loss: 0.0057 - 8ms/epoch - 2ms/step
# Epoch 55/60
# 4/4 - 0s - loss: 0.0056 - 10ms/epoch - 2ms/step
# Epoch 56/60
# 4/4 - 0s - loss: 0.0052 - 8ms/epoch - 2ms/step
# Epoch 57/60
# 4/4 - 0s - loss: 0.0048 - 9ms/epoch - 2ms/step
# Epoch 58/60
# 4/4 - 0s - loss: 0.0052 - 8ms/epoch - 2ms/step
# Epoch 59/60
# 4/4 - 0s - loss: 0.0052 - 10ms/epoch - 2ms/step
# Epoch 60/60
# 4/4 - 0s - loss: 0.0048 - 9ms/epoch - 2ms/step

# %%
predictions = model.predict(testX)
predictions = scaler_harga.inverse_transform(predictions)
testY = scaler_harga.inverse_transform(testY)
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
trainY = scaler_harga.inverse_transform(trainY)

# %% [markdown]
# # Hasil Akhir

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(testY, predictions)*100
plt.figure(figsize=(25, 6))
plt.plot(df.index[:len(trainY)], trainY, label='Training', marker='', color='blue', linestyle='-', linewidth=5)
plt.plot(df.index[-len(testY):], testY, label='Testing ', marker='', color='red', linestyle='-', linewidth=5)
plt.plot(df.index[-len(predictions):], predictions, label='Prediction', marker='', color='green', linestyle='-', linewidth=5)
plt.title(f'MAPE: {mape:.3f}%', fontsize=16)
plt.xlabel('Tanggal', fontsize=12)
plt.ylabel('Harga', fontsize=12)
plt.grid(True, linestyle='--', alpha=1)
plt.legend()
plt.xticks(rotation=0)
plt.show()
